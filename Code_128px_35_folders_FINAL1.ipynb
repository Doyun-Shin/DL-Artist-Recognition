# %% [markdown]
# <a href="https://colab.research.google.com/github/svasylyeva/AWS/blob/main/Code_128px_35_folders_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the Keras libraries and packages
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers.core import Dense, Dropout, Activation, Flatten

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import tensorflow
from sklearn.metrics import classification_report, confusion_matrix
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from numpy.random import seed
import os
from shutil import copy2
from tqdm import tqdm
from PIL import Image
import PIL
import random
from keras.optimizers import Adam
from keras.layers.normalization import BatchNormalization 

# import splitfolders library to split folder with chosen ratio
#import splitfolders
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model
from matplotlib import pyplot
from numpy import expand_dims

# %% [markdown]
# <h3>Pre-processing Part</h3>

# %%
# Pre-processing Part
# Copy files from a set of folders inside downloaded artist to one folder for every artist

# Wikiart script downloads files to the local drive
root_dir = '/Users/murmu/Documents/Deep_Learning/wikiart/wikiart-master/wikiart-saved/images/'
destination_dir = '/Users/murmu/Documents/Deep_Learning/wikiart/wikiart-master/artists/'

# Download pictures with wikiart code from WikiArt and create folders with chosen artists
# link to github project - https://github.com/lucasdavid/wikiart
# We do not show code of the script for downloading here - it could be found on the link above

# Folders of artist after wikiart work
src_artist_lst = [ 'camille-pissarro', 'claude-monet', 
                  'henri-matisse', 'pierre-auguste-renoir', 'vincent-van-gogh', 'john-singer-sargent']

# Folders of artists that we are going to use in the further work
dest_artist_lst = ['Pissaro', 'Monet', 'Matisse', 'Renoir', 'VanGogh', 'Sargent']

# Define function to copy jpegs from folders that wikiart script created on local drive
def copy_jpegs(src_artist, dest_artist):
# Define source and destination directories
    artist_src_dir = os.path.join(root_dir, src_artist)
    artist_destination_dir = os.path.join(destination_dir, dest_artist)

# Copy files from all directories inside main directory with the name of artist
# showing progress bar of the process
    for root, dirs, files in os.walk(artist_src_dir):
        for file in tqdm(files):
            path_file = os.path.join(root, file)
            source_resized_file = os.path.join(artist_destination_dir, file)

# To resize our files and avoid stretching for rectangular files we used AlexNet pre-processing approach:
# - down-sample the images to a fixed resolution of 256 × 256
# - for rectangular image, we first rescaled the image such that the shorter side was of length 256 and
# cropped out the central 256×256 part from the resulting image
            max_side = 256
            image = Image.open(path_file)
            w, h = image.size
            original_size = max(w, h)

            # If image has a rectangular shape - resize it such way 
            # that the shortest side of the image becomes 256px and crop the center
            if (w < h):
                resized_width = max_side
                resized_height = int(round((max_side/float(image.size[0]))*image.size[1]))
                # resixe image
                image = image.resize((resized_width, resized_height), Image.ANTIALIAS)
                left = 0
                top = (resized_height - max_side)/2
                right = max_side
                bottom = (resized_height + max_side)/2
                image = image.crop((left, top, right, bottom))
            else:
                resized_height = max_side
                resized_width = int(round((max_side/float(image.size[1]))*image.size[0]))
                # resixe image
                image = image.resize((resized_width, resized_height), Image.ANTIALIAS)
                left = (resized_width - max_side)/2
                top = 0
                right = (resized_width + max_side)/2
                bottom = max_side
                image = image.crop((left, top, right, bottom))
            
            # convert to RGB incase it's RGBA
            cropped_rgb_image = image.convert("RGB")
            # save resized image
            cropped_rgb_image.save(source_resized_file, image.format)

        
# Create a zip list 
zip_lst = list(zip(src_artist_lst, dest_artist_lst))

# copy files
for (src, dest) in zip_lst: 
    copy_jpegs(src, dest)
# Out:
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 21.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.66it/s]
# 100%|██████████| 3/3 [00:00<00:00, 36.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 37.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.13it/s]
# 100%|██████████| 6/6 [00:00<00:00, 26.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]
# 100%|██████████| 3/3 [00:00<00:00, 31.85it/s]
# 100%|██████████| 8/8 [00:00<00:00, 17.01it/s]
# 100%|██████████| 4/4 [00:00<00:00, 20.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.94it/s]
# 100%|██████████| 17/17 [00:00<00:00, 25.68it/s]
# 100%|██████████| 16/16 [00:00<00:00, 23.33it/s]
# 100%|██████████| 41/41 [00:02<00:00, 19.46it/s]
# 100%|██████████| 27/27 [00:01<00:00, 24.02it/s]
# 100%|██████████| 38/38 [00:02<00:00, 17.45it/s]
# 100%|██████████| 25/25 [00:00<00:00, 32.44it/s]
# 100%|██████████| 15/15 [00:00<00:00, 34.27it/s]
# 100%|██████████| 18/18 [00:00<00:00, 29.15it/s]
# 100%|██████████| 14/14 [00:00<00:00, 39.64it/s]
# 100%|██████████| 20/20 [00:00<00:00, 39.94it/s]
# 100%|██████████| 16/16 [00:00<00:00, 40.03it/s]
# 100%|██████████| 20/20 [00:00<00:00, 35.30it/s]
# 100%|██████████| 24/24 [00:00<00:00, 40.44it/s]
# 100%|██████████| 27/27 [00:00<00:00, 36.38it/s]
# 100%|██████████| 14/14 [00:00<00:00, 41.04it/s]
# 100%|██████████| 15/15 [00:00<00:00, 38.02it/s]
# 100%|██████████| 12/12 [00:00<00:00, 36.61it/s]
# 100%|██████████| 13/13 [00:00<00:00, 40.63it/s]
# 100%|██████████| 16/16 [00:00<00:00, 39.21it/s]
# 100%|██████████| 8/8 [00:00<00:00, 42.42it/s]
# 100%|██████████| 35/35 [00:00<00:00, 41.84it/s]
# 100%|██████████| 18/18 [00:00<00:00, 38.09it/s]
# 100%|██████████| 27/27 [00:00<00:00, 35.66it/s]
# 100%|██████████| 19/19 [00:00<00:00, 38.20it/s]
# 100%|██████████| 14/14 [00:00<00:00, 30.54it/s]
# 100%|██████████| 21/21 [00:00<00:00, 28.21it/s]
# 100%|██████████| 26/26 [00:00<00:00, 29.01it/s]
# 100%|██████████| 32/32 [00:01<00:00, 30.37it/s]
# 100%|██████████| 35/35 [00:01<00:00, 27.25it/s]
# 100%|██████████| 25/25 [00:00<00:00, 40.17it/s]
# 100%|██████████| 27/27 [00:00<00:00, 35.43it/s]
# 100%|██████████| 35/35 [00:00<00:00, 39.80it/s]
# 100%|██████████| 38/38 [00:01<00:00, 36.60it/s]
# 100%|██████████| 22/22 [00:00<00:00, 41.09it/s]
# 100%|██████████| 71/71 [00:02<00:00, 32.26it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 33.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.72it/s]
# 100%|██████████| 2/2 [00:00<00:00, 33.75it/s]
# 100%|██████████| 19/19 [00:00<00:00, 24.85it/s]
# 100%|██████████| 19/19 [00:00<00:00, 19.61it/s]
# 100%|██████████| 18/18 [00:01<00:00, 16.65it/s]
# 100%|██████████| 16/16 [00:00<00:00, 20.15it/s]
# 100%|██████████| 13/13 [00:00<00:00, 18.19it/s]
# 100%|██████████| 13/13 [00:00<00:00, 24.83it/s]
# 100%|██████████| 13/13 [00:00<00:00, 19.80it/s]
# 100%|██████████| 33/33 [00:01<00:00, 24.46it/s]
# 100%|██████████| 49/49 [00:02<00:00, 17.75it/s]
# 100%|██████████| 36/36 [00:02<00:00, 16.49it/s]
# 100%|██████████| 41/41 [00:02<00:00, 20.13it/s]
# 100%|██████████| 37/37 [00:02<00:00, 12.70it/s]
# 100%|██████████| 31/31 [00:01<00:00, 19.10it/s]
# 100%|██████████| 16/16 [00:00<00:00, 23.29it/s]
# 100%|██████████| 34/34 [00:01<00:00, 18.86it/s]
# 100%|██████████| 28/28 [00:01<00:00, 17.40it/s]
# 100%|██████████| 58/58 [00:03<00:00, 15.80it/s]
# 100%|██████████| 51/51 [00:02<00:00, 18.27it/s]
# 100%|██████████| 74/74 [00:04<00:00, 16.68it/s]
# 100%|██████████| 42/42 [00:02<00:00, 15.99it/s]
# 100%|██████████| 50/50 [00:02<00:00, 17.03it/s]
# 100%|██████████| 54/54 [00:02<00:00, 21.32it/s]
# 100%|██████████| 46/46 [00:02<00:00, 18.34it/s]
# 100%|██████████| 21/21 [00:01<00:00, 15.32it/s]
# 100%|██████████| 42/42 [00:02<00:00, 16.63it/s]
# 100%|██████████| 24/24 [00:01<00:00, 21.76it/s]
# 100%|██████████| 13/13 [00:01<00:00,  8.06it/s]
# 100%|██████████| 39/39 [00:06<00:00,  6.44it/s]
# 100%|██████████| 7/7 [00:00<00:00, 19.43it/s]
# 100%|██████████| 11/11 [00:00<00:00, 17.45it/s]
# 100%|██████████| 36/36 [00:02<00:00, 16.30it/s]
# 100%|██████████| 16/16 [00:00<00:00, 19.06it/s]
# 100%|██████████| 12/12 [00:00<00:00, 15.42it/s]
# 100%|██████████| 39/39 [00:01<00:00, 26.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.52it/s]
# 100%|██████████| 11/11 [00:00<00:00, 18.52it/s]
# 100%|██████████| 13/13 [00:00<00:00, 13.39it/s]
# 100%|██████████| 31/31 [00:01<00:00, 22.37it/s]
# 100%|██████████| 7/7 [00:00<00:00, 26.17it/s]
# 100%|██████████| 29/29 [00:01<00:00, 17.70it/s]
# 100%|██████████| 13/13 [00:00<00:00, 15.91it/s]
# 100%|██████████| 9/9 [00:00<00:00, 16.02it/s]
# 100%|██████████| 4/4 [00:00<00:00, 15.99it/s]
# 100%|██████████| 16/16 [00:00<00:00, 23.34it/s]
# 100%|██████████| 42/42 [00:02<00:00, 19.34it/s]
# 100%|██████████| 3/3 [00:00<00:00, 17.44it/s]
# 100%|██████████| 4/4 [00:00<00:00, 23.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.84it/s]
# 100%|██████████| 2/2 [00:00<00:00, 10.88it/s]
# 100%|██████████| 33/33 [00:01<00:00, 20.44it/s]
# 100%|██████████| 4/4 [00:00<00:00, 17.43it/s]
# 100%|██████████| 39/39 [00:02<00:00, 19.44it/s]
# 100%|██████████| 10/10 [00:00<00:00, 29.01it/s]
# 100%|██████████| 7/7 [00:00<00:00, 10.15it/s]
# 100%|██████████| 20/20 [00:00<00:00, 22.65it/s]
# 100%|██████████| 4/4 [00:00<00:00, 31.18it/s]
# 100%|██████████| 9/9 [00:00<00:00, 32.94it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 30.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.82it/s]
# 100%|██████████| 2/2 [00:00<00:00, 49.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 16.12it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.94it/s]
# 100%|██████████| 22/22 [00:00<00:00, 28.18it/s]
# 100%|██████████| 11/11 [00:00<00:00, 23.59it/s]
# 100%|██████████| 23/23 [00:00<00:00, 36.88it/s]
# 100%|██████████| 8/8 [00:00<00:00, 34.56it/s]
# 100%|██████████| 13/13 [00:00<00:00, 28.47it/s]
# 100%|██████████| 12/12 [00:00<00:00, 27.74it/s]
# 100%|██████████| 9/9 [00:00<00:00, 32.22it/s]
# 100%|██████████| 20/20 [00:00<00:00, 38.56it/s]
# 100%|██████████| 19/19 [00:00<00:00, 19.68it/s]
# 100%|██████████| 30/30 [00:01<00:00, 20.67it/s]
# 100%|██████████| 30/30 [00:01<00:00, 28.57it/s]
# 100%|██████████| 25/25 [00:00<00:00, 28.10it/s]
# 100%|██████████| 17/17 [00:00<00:00, 25.57it/s]
# 100%|██████████| 18/18 [00:00<00:00, 25.13it/s]
# 100%|██████████| 7/7 [00:00<00:00, 17.65it/s]
# 100%|██████████| 14/14 [00:01<00:00,  9.79it/s]
# 100%|██████████| 22/22 [00:00<00:00, 22.14it/s]
# 100%|██████████| 17/17 [00:00<00:00, 24.31it/s]
# 100%|██████████| 14/14 [00:00<00:00, 20.99it/s]
# 100%|██████████| 4/4 [00:00<00:00, 17.87it/s]
# 100%|██████████| 27/27 [00:01<00:00, 21.80it/s]
# 100%|██████████| 54/54 [00:02<00:00, 26.09it/s]
# 100%|██████████| 42/42 [00:01<00:00, 30.92it/s]
# 100%|██████████| 56/56 [00:02<00:00, 24.23it/s]
# 100%|██████████| 43/43 [00:01<00:00, 35.91it/s]
# 100%|██████████| 38/38 [00:01<00:00, 30.44it/s]
# 100%|██████████| 27/27 [00:00<00:00, 40.04it/s]
# 100%|██████████| 29/29 [00:01<00:00, 20.45it/s]
# 100%|██████████| 21/21 [00:00<00:00, 29.21it/s]
# 100%|██████████| 13/13 [00:00<00:00, 37.14it/s]
# 100%|██████████| 15/15 [00:00<00:00, 33.88it/s]
# 100%|██████████| 11/11 [00:00<00:00, 37.95it/s]
# 100%|██████████| 9/9 [00:00<00:00, 31.93it/s]
# 100%|██████████| 7/7 [00:00<00:00, 37.95it/s]
# 100%|██████████| 4/4 [00:00<00:00, 37.50it/s]
# 100%|██████████| 2/2 [00:00<00:00, 23.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.87it/s]
# 100%|██████████| 3/3 [00:00<00:00, 83.74it/s]
# 100%|██████████| 4/4 [00:00<00:00, 33.01it/s]
# 100%|██████████| 12/12 [00:00<00:00, 43.44it/s]
# 100%|██████████| 16/16 [00:00<00:00, 48.19it/s]
# 100%|██████████| 18/18 [00:00<00:00, 31.91it/s]
# 100%|██████████| 7/7 [00:00<00:00, 27.42it/s]
# 100%|██████████| 12/12 [00:00<00:00, 27.89it/s]
# 100%|██████████| 18/18 [00:00<00:00, 32.05it/s]
# 100%|██████████| 14/14 [00:00<00:00, 37.74it/s]
# 100%|██████████| 26/26 [00:00<00:00, 47.05it/s]
# 100%|██████████| 18/18 [00:00<00:00, 47.01it/s]
# 100%|██████████| 12/12 [00:00<00:00, 58.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 41.90it/s]
# 100%|██████████| 10/10 [00:00<00:00, 21.07it/s]
# 100%|██████████| 24/24 [00:00<00:00, 46.55it/s]
# 100%|██████████| 7/7 [00:00<00:00, 24.39it/s]
# 100%|██████████| 2/2 [00:00<00:00, 33.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 36.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 51.54it/s]
# 100%|██████████| 11/11 [00:00<00:00, 29.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.61it/s]
# 100%|██████████| 32/32 [00:01<00:00, 17.17it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.83it/s]
# 100%|██████████| 2/2 [00:00<00:00, 44.02it/s]
# 100%|██████████| 2/2 [00:00<00:00, 38.42it/s]
# 100%|██████████| 4/4 [00:00<00:00, 30.21it/s]
# 100%|██████████| 2/2 [00:00<00:00, 26.07it/s]
# 100%|██████████| 7/7 [00:00<00:00, 20.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.10it/s]
# 100%|██████████| 7/7 [00:00<00:00, 19.75it/s]
# 100%|██████████| 7/7 [00:00<00:00, 36.12it/s]
# 100%|██████████| 10/10 [00:00<00:00, 27.72it/s]
# 100%|██████████| 11/11 [00:00<00:00, 34.40it/s]
# 100%|██████████| 15/15 [00:00<00:00, 29.67it/s]
# 100%|██████████| 12/12 [00:00<00:00, 30.06it/s]
# 100%|██████████| 19/19 [00:00<00:00, 31.92it/s]
# 100%|██████████| 42/42 [00:01<00:00, 31.89it/s]
# 100%|██████████| 54/54 [00:02<00:00, 26.00it/s]
# 100%|██████████| 26/26 [00:00<00:00, 34.78it/s]
# 100%|██████████| 21/21 [00:00<00:00, 27.93it/s]
# 100%|██████████| 36/36 [00:01<00:00, 35.96it/s]
# 100%|██████████| 44/44 [00:01<00:00, 31.27it/s]
# 100%|██████████| 46/46 [00:01<00:00, 33.11it/s]
# 100%|██████████| 25/25 [00:00<00:00, 29.08it/s]
# 100%|██████████| 34/34 [00:00<00:00, 35.56it/s]
# 100%|██████████| 13/13 [00:00<00:00, 40.90it/s]
# 100%|██████████| 26/26 [00:00<00:00, 35.43it/s]
# 100%|██████████| 10/10 [00:00<00:00, 34.18it/s]
# 100%|██████████| 23/23 [00:00<00:00, 38.31it/s]
# 100%|██████████| 19/19 [00:00<00:00, 38.42it/s]
# 100%|██████████| 20/20 [00:00<00:00, 31.36it/s]
# 100%|██████████| 52/52 [00:01<00:00, 42.48it/s]
# 100%|██████████| 9/9 [00:00<00:00, 24.55it/s]
# 100%|██████████| 25/25 [00:00<00:00, 30.22it/s]
# 100%|██████████| 14/14 [00:00<00:00, 34.58it/s]
# 100%|██████████| 16/16 [00:00<00:00, 47.64it/s]
# 100%|██████████| 54/54 [00:01<00:00, 37.52it/s]
# 100%|██████████| 19/19 [00:00<00:00, 38.70it/s]
# 100%|██████████| 18/18 [00:00<00:00, 43.72it/s]
# 100%|██████████| 18/18 [00:00<00:00, 35.48it/s]
# 100%|██████████| 9/9 [00:00<00:00, 35.01it/s]
# 100%|██████████| 33/33 [00:00<00:00, 39.01it/s]
# 100%|██████████| 14/14 [00:00<00:00, 40.88it/s]
# 100%|██████████| 9/9 [00:00<00:00, 26.89it/s]
# 100%|██████████| 11/11 [00:00<00:00, 44.41it/s]
# 100%|██████████| 10/10 [00:00<00:00, 27.73it/s]
# 100%|██████████| 38/38 [00:01<00:00, 36.01it/s]
# 100%|██████████| 18/18 [00:00<00:00, 38.13it/s]
# 100%|██████████| 11/11 [00:00<00:00, 45.90it/s]
# 100%|██████████| 20/20 [00:00<00:00, 31.42it/s]
# 100%|██████████| 20/20 [00:00<00:00, 40.40it/s]
# 100%|██████████| 52/52 [00:01<00:00, 36.10it/s]
# 100%|██████████| 8/8 [00:00<00:00, 29.67it/s]
# 100%|██████████| 16/16 [00:00<00:00, 41.00it/s]
# 100%|██████████| 16/16 [00:00<00:00, 32.58it/s]
# 100%|██████████| 12/12 [00:00<00:00, 39.44it/s]
# 100%|██████████| 23/23 [00:00<00:00, 36.75it/s]
# 100%|██████████| 19/19 [00:00<00:00, 38.43it/s]
# 100%|██████████| 22/22 [00:01<00:00, 20.10it/s]
# 100%|██████████| 16/16 [00:00<00:00, 38.64it/s]
# 100%|██████████| 18/18 [00:00<00:00, 39.52it/s]
# 100%|██████████| 249/249 [00:08<00:00, 30.90it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 4/4 [00:00<00:00, 17.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 58.77it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.57it/s]
# 100%|██████████| 4/4 [00:00<00:00, 15.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 20.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 42.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 27.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.10it/s]
# 100%|██████████| 4/4 [00:00<00:00, 11.54it/s]
# 100%|██████████| 3/3 [00:00<00:00, 38.79it/s]
# 100%|██████████| 78/78 [00:02<00:00, 26.12it/s]
# 100%|██████████| 190/190 [00:07<00:00, 23.91it/s]
# 100%|██████████| 125/125 [00:05<00:00, 23.19it/s]
# 100%|██████████| 104/104 [00:04<00:00, 24.30it/s]
# 100%|██████████| 328/328 [00:14<00:00, 22.83it/s]
# 100%|██████████| 161/161 [00:09<00:00, 17.32it/s]
# 100%|██████████| 178/178 [00:12<00:00, 13.89it/s]
# 100%|██████████| 292/292 [00:15<00:00, 18.26it/s]
# 100%|██████████| 209/209 [00:12<00:00, 16.68it/s]
# 100%|██████████| 238/238 [00:11<00:00, 20.67it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 48.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.99it/s]
# 100%|██████████| 3/3 [00:00<00:00, 49.10it/s]
# 100%|██████████| 4/4 [00:00<00:00, 45.86it/s]
# 100%|██████████| 4/4 [00:00<00:00, 20.09it/s]
# 100%|██████████| 16/16 [00:00<00:00, 16.37it/s]
# 100%|██████████| 14/14 [00:00<00:00, 40.44it/s]
# 100%|██████████| 13/13 [00:00<00:00, 25.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 46.02it/s]
# 100%|██████████| 34/34 [00:01<00:00, 27.94it/s]
# 100%|██████████| 12/12 [00:00<00:00, 28.31it/s]
# 100%|██████████| 25/25 [00:00<00:00, 32.84it/s]
# 100%|██████████| 27/27 [00:00<00:00, 36.28it/s]
# 100%|██████████| 20/20 [00:00<00:00, 25.02it/s]
# 100%|██████████| 16/16 [00:00<00:00, 29.82it/s]
# 100%|██████████| 21/21 [00:00<00:00, 31.85it/s]
# 100%|██████████| 19/19 [00:00<00:00, 33.53it/s]
# 100%|██████████| 21/21 [00:00<00:00, 30.20it/s]
# 100%|██████████| 10/10 [00:00<00:00, 37.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 49.03it/s]
# 100%|██████████| 8/8 [00:00<00:00, 21.08it/s]
# 100%|██████████| 6/6 [00:00<00:00, 49.95it/s]
# 100%|██████████| 12/12 [00:00<00:00, 48.33it/s]
# 100%|██████████| 12/12 [00:00<00:00, 38.97it/s]
# 100%|██████████| 7/7 [00:00<00:00, 27.51it/s]
# 100%|██████████| 17/17 [00:00<00:00, 37.11it/s]
# 100%|██████████| 9/9 [00:00<00:00, 37.68it/s]
# 100%|██████████| 7/7 [00:00<00:00, 40.00it/s]
# 100%|██████████| 13/13 [00:00<00:00, 52.13it/s]
# 100%|██████████| 26/26 [00:00<00:00, 33.91it/s]
# 100%|██████████| 26/26 [00:00<00:00, 38.99it/s]
# 100%|██████████| 23/23 [00:00<00:00, 41.73it/s]
# 100%|██████████| 27/27 [00:00<00:00, 39.94it/s]
# 100%|██████████| 32/32 [00:00<00:00, 32.70it/s]
# 100%|██████████| 47/47 [00:01<00:00, 34.55it/s]
# 100%|██████████| 35/35 [00:00<00:00, 36.06it/s]
# 100%|██████████| 22/22 [00:00<00:00, 35.75it/s]
# 100%|██████████| 26/26 [00:00<00:00, 34.98it/s]
# 100%|██████████| 22/22 [00:00<00:00, 37.79it/s]
# 100%|██████████| 16/16 [00:00<00:00, 31.54it/s]
# 100%|██████████| 17/17 [00:00<00:00, 43.92it/s]
# 100%|██████████| 9/9 [00:00<00:00, 42.38it/s]
# 100%|██████████| 6/6 [00:00<00:00, 52.01it/s]
# 100%|██████████| 2/2 [00:00<00:00, 38.45it/s]
# 100%|██████████| 14/14 [00:00<00:00, 39.44it/s]
# 100%|██████████| 9/9 [00:00<00:00, 16.75it/s]
# 100%|██████████| 2/2 [00:00<00:00, 12.88it/s]
# 100%|██████████| 10/10 [00:00<00:00, 33.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 44.14it/s]
# 100%|██████████| 3/3 [00:00<00:00, 58.06it/s]
# 100%|██████████| 4/4 [00:00<00:00, 55.38it/s]
# 100%|██████████| 9/9 [00:00<00:00, 28.21it/s]
# 100%|██████████| 45/45 [00:00<00:00, 61.50it/s]

# %%
# We begin to work with images of size 128*128px for 30 epochs
# for our baseline models
img_rows = 128
img_cols = 128
epochs = 30
batch_size = 64

# %%
# Plot diagnostic learning curves from history
def graph_accuracy_loss(history):
    pyplot.figure(figsize=(10,5))
    # Plot loss
    pyplot.subplot(121)
    pyplot.title('Entropy Loss')
    pyplot.plot(history.history['loss'], color='green', label='train')
    pyplot.plot(history.history['val_loss'], color='blue', label='test')
    pyplot.legend()
    # Plot accuracy
    pyplot.subplot(122)
    pyplot.title('\nClassification Accuracy')
    pyplot.plot(history.history['accuracy'], color='green', label='train')
    pyplot.plot(history.history['val_accuracy'], color='blue', label='test')
    pyplot.legend()
    # Show plot
    pyplot.show()

# %%
# Function that calculates Confusion Matrix and shows Classification Report
def class_report(test_set, model):
# Predict with our model
    Y_pred = model.predict(test_set, num_of_test_samples // batch_size + 1)
    y_pred = np.argmax(Y_pred, axis=1)
    print('Confusion Matrix')
# Use confusion_matrix from sklearn
    print(confusion_matrix(test_set.classes, y_pred))
    print('Classification Report')
    target_names = list(training_set.class_indices.keys())
    print(classification_report(test_set.classes, y_pred, target_names=target_names))

# %%
# Import and work with splitfolders 
#link - https://pypi.org/project/split-folders/

# Divide all artists folders to train and val folders
splitfolders.ratio("./artists", output="./", seed=42 , ratio=(.7, .3))

# %%
# Prepare the data. Instanciate ImageDataGenerator that generates batches of image data 
# scaling the pixel values to the range of 0-1.
# We don't use data augmentation, dropout etc for the Baseline models to check a minimal model performance 
datagen = ImageDataGenerator(rescale=1. / 255)

# Use train folder that was created with splitfolders for creating training set
training_set = datagen.flow_from_directory('train', 
                                                 target_size=(img_rows, img_cols),
                                                 batch_size=batch_size,
                                                 class_mode='categorical')

# Use val folder that was created with splitfolders for creating validation set
test_set = datagen.flow_from_directory('val',
                                            target_size=(img_rows, img_cols),
                                            batch_size=batch_size, shuffle = False,
                                            class_mode='categorical')
# Out:
# Found 3360 images belonging to 6 classes.
# Found 1440 images belonging to 6 classes.

# %%
# Define number of samnples for train and test sets
num_of_train_samples = training_set.n
num_of_test_samples = test_set.n

# %%
# Print our classes 
print(test_set.class_indices)
# Out:
# {'Matisse': 0, 'Monet': 1, 'Pissaro': 2, 'Renoir': 3, 'Sargent': 4, 'VanGogh': 5}

# %%
# Define the list with artists names
artists_name = os.listdir('artists')

# Plot 10 random paintings
rows = 2
cols = 5
fig, axes = plt.subplots(figsize=(18,7))
axes=[]
for i in range(rows*cols):
    axes.append( fig.add_subplot(rows, cols, i+1) )
    random_artist = random.choice(artists_name)
    random_image = random.choice(os.listdir(os.path.join('artists', random_artist)))
    random_image_file = os.path.join('artists', random_artist, random_image)
    image = plt.imread(random_image_file)
    ax = pyplot.subplot(rows, cols, i+1)
    axes[i].imshow(image)
    axes[i].set_title("Artist: " + random_artist.replace('_', ' '))
    axes[i].axis('off')
    axes[i].axis('off')

plt.show()

# %%
# VGG Blocks
# One VGG block consists of a sequence of convolutional layers, followed by a max pooling layer for spatial downsampling. 
# The authors employed convolutions with  3×3  kernels with padding of 1 (keeping height and width) 
# and  2×2  max pooling with stride of 2 (halving the resolution after each block).

# %% [markdown]
# <h3>Baseline model with 1 VGG block without dropout</h3>

# %%
# Part 1 - Develop a Baseline CNN Models:
# Define CNN model with one VGG-style block
# The 1-block VGG model has a single convolutional layer with 32 filters 
# followed by a max pooling layer
def baseline_model_1():
    
    model = Sequential()
# Add two 2D convolution layers with 32 filters. 
# Each Conv2D layer will have the ReLU activation and the “he_uniform” weight initialization (generally best practices)
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', 
                     input_shape=(img_rows, img_cols, 3)))
    model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
# Add MaxPooling layer for downsampling
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    
    model.add(Flatten())
# Fully-connected layers
    model.add(Dense(128, activation='relu', 
                    kernel_initializer='he_uniform'))
    model.add(Dense(6, activation='softmax'))
    
# Compilation of a model    
# The model will be optimized using stochastic gradient descent. 
# with a learning rate of 0.001 and a momentum of 0.9. 
    opt = SGD(lr=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# The model will be fit for 30 epochs - to check model's accuracy
# Define model
model = baseline_model_1()
# Fit model
history = model.fit_generator(training_set, 
                              steps_per_epoch=len(training_set), # = num_of_train_samples // batch_size +1
                              validation_data=test_set, 
                              validation_steps=len(test_set), # = num_of_test_samples // batch_size +1
                              epochs= epochs)
# Out:
# Epoch 1/35
# 53/53 [==============================] - 74s 1s/step - loss: 1.9967 - accuracy: 0.2219 - val_loss: 1.6657 - val_accuracy: 0.3076
# Epoch 2/35
# 53/53 [==============================] - 56s 1s/step - loss: 1.5780 - accuracy: 0.3796 - val_loss: 1.4520 - val_accuracy: 0.4535
# Epoch 3/35
# 53/53 [==============================] - 56s 1s/step - loss: 1.4486 - accuracy: 0.4522 - val_loss: 1.4351 - val_accuracy: 0.4556
# Epoch 4/35
# 53/53 [==============================] - 56s 1s/step - loss: 1.3848 - accuracy: 0.4798 - val_loss: 1.3873 - val_accuracy: 0.4653
# Epoch 5/35
# 53/53 [==============================] - 58s 1s/step - loss: 1.2973 - accuracy: 0.5251 - val_loss: 1.3587 - val_accuracy: 0.4847
# Epoch 6/35
# 53/53 [==============================] - 56s 1s/step - loss: 1.2096 - accuracy: 0.5822 - val_loss: 1.3505 - val_accuracy: 0.4938
# Epoch 7/35
# 53/53 [==============================] - 54s 1s/step - loss: 1.1968 - accuracy: 0.5805 - val_loss: 1.3719 - val_accuracy: 0.4708
# Epoch 8/35
# 53/53 [==============================] - 55s 1s/step - loss: 1.1696 - accuracy: 0.5686 - val_loss: 1.3938 - val_accuracy: 0.4778
# Epoch 9/35
# 53/53 [==============================] - 56s 1s/step - loss: 1.0505 - accuracy: 0.6297 - val_loss: 1.2957 - val_accuracy: 0.5153
# Epoch 10/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.9759 - accuracy: 0.6607 - val_loss: 1.3563 - val_accuracy: 0.4826
# Epoch 11/35
# 53/53 [==============================] - 55s 1s/step - loss: 0.8426 - accuracy: 0.7157 - val_loss: 1.3481 - val_accuracy: 0.4924
# Epoch 12/35
# 53/53 [==============================] - 58s 1s/step - loss: 0.7759 - accuracy: 0.7403 - val_loss: 1.3094 - val_accuracy: 0.5167
# Epoch 13/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.6528 - accuracy: 0.8123 - val_loss: 1.3651 - val_accuracy: 0.5083
# Epoch 14/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.5667 - accuracy: 0.8305 - val_loss: 1.4311 - val_accuracy: 0.4979
# Epoch 15/35
# 53/53 [==============================] - 55s 1s/step - loss: 0.4954 - accuracy: 0.8658 - val_loss: 1.4173 - val_accuracy: 0.5021
# Epoch 16/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.3859 - accuracy: 0.9068 - val_loss: 1.3525 - val_accuracy: 0.5222
# Epoch 17/35
# 53/53 [==============================] - 55s 1s/step - loss: 0.2889 - accuracy: 0.9393 - val_loss: 1.4936 - val_accuracy: 0.4979
# Epoch 18/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.2481 - accuracy: 0.9529 - val_loss: 1.4528 - val_accuracy: 0.5146
# Epoch 19/35
# 53/53 [==============================] - 58s 1s/step - loss: 0.2184 - accuracy: 0.9562 - val_loss: 1.5991 - val_accuracy: 0.4993
# Epoch 20/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.1777 - accuracy: 0.9690 - val_loss: 1.5141 - val_accuracy: 0.5264
# Epoch 21/35
# 53/53 [==============================] - 55s 1s/step - loss: 0.1144 - accuracy: 0.9878 - val_loss: 1.5931 - val_accuracy: 0.5188
# Epoch 22/35
# 53/53 [==============================] - 55s 1s/step - loss: 0.0858 - accuracy: 0.9931 - val_loss: 1.7094 - val_accuracy: 0.5056
# Epoch 23/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.0757 - accuracy: 0.9901 - val_loss: 1.7247 - val_accuracy: 0.5167
# Epoch 24/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.0623 - accuracy: 0.9951 - val_loss: 1.6895 - val_accuracy: 0.5257
# Epoch 25/35
# 53/53 [==============================] - 55s 1s/step - loss: 0.0427 - accuracy: 0.9976 - val_loss: 1.7745 - val_accuracy: 0.5111
# Epoch 26/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.0357 - accuracy: 0.9998 - val_loss: 1.7909 - val_accuracy: 0.5132
# Epoch 27/35
# 53/53 [==============================] - 58s 1s/step - loss: 0.0328 - accuracy: 0.9992 - val_loss: 1.8464 - val_accuracy: 0.5063
# Epoch 28/35
# 53/53 [==============================] - 57s 1s/step - loss: 0.0295 - accuracy: 0.9982 - val_loss: 1.8450 - val_accuracy: 0.5181
# Epoch 29/35
# 53/53 [==============================] - 57s 1s/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 1.8514 - val_accuracy: 0.5104
# Epoch 30/35
# 53/53 [==============================] - 58s 1s/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 1.8901 - val_accuracy: 0.5097
# Epoch 31/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 1.9573 - val_accuracy: 0.5153
# Epoch 32/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 1.9839 - val_accuracy: 0.5097
# Epoch 33/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 1.9717 - val_accuracy: 0.5097
# Epoch 34/35
# 53/53 [==============================] - 56s 1s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 2.0161 - val_accuracy: 0.5069
# Epoch 35/35
# 53/53 [==============================] - 54s 1s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 2.0137 - val_accuracy: 0.5118

# %%
# Evaluate model
_, acc = model.evaluate_generator(test_set, steps=len(test_set), verbose=0)
print("Accuracy: %.4f" % (acc * 100.0))
# Out:
# Accuracy: 51.1806

# %%
# Build graphs of entropy loss and accuracy
graph_accuracy_loss(history)

# %%
# Build a classification report
class_report(test_set, model)
# Out:
# Confusion Matrix
# [[109  37  15  32  21  26]
#  [ 16 129  40   8  11  36]
#  [ 12  33 134  24  11  26]
#  [ 17  14  20 139  22  28]
#  [ 38  19  20  33 110  20]
#  [ 18  22  36  31  17 116]]
# Classification Report
#               precision    recall  f1-score   support
#
#      Matisse       0.52      0.45      0.48       240
#        Monet       0.51      0.54      0.52       240
#      Pissaro       0.51      0.56      0.53       240
#       Renoir       0.52      0.58      0.55       240
#      Sargent       0.57      0.46      0.51       240
#      VanGogh       0.46      0.48      0.47       240
#
#     accuracy                           0.51      1440
#    macro avg       0.51      0.51      0.51      1440
# weighted avg       0.51      0.51      0.51      1440

# %%
# As we see our 1-vgg block model is over-fitting on a training set

# %% [markdown]
# <h3>Baseline model with 2 VGG blocks without dropout</h3>

# %%
# Define CNN model with two VGG-style blocks according to the principle explained earlier
def baseline_model_2():
   # reset_random_seeds()
    model = Sequential()
# 1st block    
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', 
                     input_shape=(img_rows, img_cols, 3)))
    model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

# 2d block    
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(64,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
   
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(6, activation='softmax'))
# Compilation of a model
    opt = SGD(lr=0.001, momentum=0.9) # Gradient descent (with momentum) optimizer.
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# The model will be fit for 30 epochs 
# define model
model = baseline_model_2()
# fit model
history = model.fit_generator(training_set, steps_per_epoch=len(training_set),
                              validation_data=test_set, 
                              validation_steps=len(test_set), 
                              epochs= epochs)
# Out:
# Epoch 1/25
# 53/53 [==============================] - 95s 2s/step - loss: 1.8804 - accuracy: 0.2391 - val_loss: 1.5255 - val_accuracy: 0.4465
# Epoch 2/25
# 53/53 [==============================] - 93s 2s/step - loss: 1.4949 - accuracy: 0.4416 - val_loss: 1.5273 - val_accuracy: 0.3806
# Epoch 3/25
# 53/53 [==============================] - 94s 2s/step - loss: 1.4085 - accuracy: 0.4545 - val_loss: 1.3900 - val_accuracy: 0.4938
# Epoch 4/25
# 53/53 [==============================] - 94s 2s/step - loss: 1.3073 - accuracy: 0.5134 - val_loss: 1.3347 - val_accuracy: 0.4944
# Epoch 5/25
# 53/53 [==============================] - 92s 2s/step - loss: 1.1953 - accuracy: 0.5544 - val_loss: 1.3934 - val_accuracy: 0.5201
# Epoch 6/25
# 53/53 [==============================] - 93s 2s/step - loss: 1.1147 - accuracy: 0.5967 - val_loss: 1.2434 - val_accuracy: 0.5465
# Epoch 7/25
# 53/53 [==============================] - 92s 2s/step - loss: 0.9786 - accuracy: 0.6673 - val_loss: 1.3812 - val_accuracy: 0.4646
# Epoch 8/25
# 53/53 [==============================] - 94s 2s/step - loss: 0.9304 - accuracy: 0.6755 - val_loss: 1.3317 - val_accuracy: 0.5049
# Epoch 9/25
# 53/53 [==============================] - 96s 2s/step - loss: 0.8284 - accuracy: 0.7135 - val_loss: 1.2739 - val_accuracy: 0.5535
# Epoch 10/25
# 53/53 [==============================] - 93s 2s/step - loss: 0.6931 - accuracy: 0.7782 - val_loss: 1.3242 - val_accuracy: 0.5340
# Epoch 11/25
# 53/53 [==============================] - 93s 2s/step - loss: 0.5722 - accuracy: 0.8143 - val_loss: 1.3172 - val_accuracy: 0.5347
# Epoch 12/25
# 53/53 [==============================] - 93s 2s/step - loss: 0.4839 - accuracy: 0.8517 - val_loss: 1.6531 - val_accuracy: 0.4993
# Epoch 13/25
# 53/53 [==============================] - 92s 2s/step - loss: 0.3774 - accuracy: 0.8893 - val_loss: 1.4228 - val_accuracy: 0.5465
# Epoch 14/25
# 53/53 [==============================] - 93s 2s/step - loss: 0.2908 - accuracy: 0.9156 - val_loss: 1.6943 - val_accuracy: 0.5201
# Epoch 15/25
# 53/53 [==============================] - 95s 2s/step - loss: 0.2100 - accuracy: 0.9427 - val_loss: 1.7262 - val_accuracy: 0.5014
# Epoch 16/25
# 53/53 [==============================] - 93s 2s/step - loss: 0.1751 - accuracy: 0.9587 - val_loss: 1.7481 - val_accuracy: 0.5431
# Epoch 17/25
# 53/53 [==============================] - 95s 2s/step - loss: 0.0892 - accuracy: 0.9870 - val_loss: 1.8935 - val_accuracy: 0.5535
# Epoch 18/25
# 53/53 [==============================] - 92s 2s/step - loss: 0.0653 - accuracy: 0.9878 - val_loss: 2.0259 - val_accuracy: 0.5549
# Epoch 19/25
# 53/53 [==============================] - 93s 2s/step - loss: 0.0373 - accuracy: 0.9966 - val_loss: 2.2792 - val_accuracy: 0.5312
# Epoch 20/25
# 53/53 [==============================] - 97s 2s/step - loss: 0.0382 - accuracy: 0.9974 - val_loss: 2.1962 - val_accuracy: 0.5424
# Epoch 21/25
# 53/53 [==============================] - 93s 2s/step - loss: 0.0223 - accuracy: 0.9993 - val_loss: 2.2241 - val_accuracy: 0.5500
# Epoch 22/25
# 53/53 [==============================] - 94s 2s/step - loss: 0.0176 - accuracy: 0.9990 - val_loss: 2.3137 - val_accuracy: 0.5521
# Epoch 23/25
# 53/53 [==============================] - 92s 2s/step - loss: 0.0102 - accuracy: 0.9996 - val_loss: 2.3934 - val_accuracy: 0.5444
# Epoch 24/25
# 53/53 [==============================] - 94s 2s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 2.4437 - val_accuracy: 0.5333
# Epoch 25/25
# 53/53 [==============================] - 96s 2s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 2.5427 - val_accuracy: 0.5451

# %%
# Evaluate model
_, acc = model.evaluate_generator(test_set, steps=len(test_set), verbose=0)
print("Accuracy: %.4f" % (acc * 100.0))
# Out:
# Accuracy: 54.5139

# %%
# Build a classification report
class_report(test_set, model)
# Out:
# Confusion Matrix
# [[147   8  15  30  19  21]
#  [ 23 121  45  16  16  19]
#  [ 24  17 157  18   8  16]
#  [ 32   9  20 139  24  16]
#  [ 54   7  26  29 112  12]
#  [ 27  10  49  25  20 109]]
# Classification Report
#               precision    recall  f1-score   support
#
#      Matisse       0.48      0.61      0.54       240
#        Monet       0.70      0.50      0.59       240
#      Pissaro       0.50      0.65      0.57       240
#       Renoir       0.54      0.58      0.56       240
#      Sargent       0.56      0.47      0.51       240
#      VanGogh       0.56      0.45      0.50       240
#
#     accuracy                           0.55      1440
#    macro avg       0.56      0.55      0.54      1440
# weighted avg       0.56      0.55      0.54      1440

# %%
# Build graphs of entropy loss and accuracy
graph_accuracy_loss(histvory)

# %%
# As we see our 2-vgg block model is over-fitting on a training set as well

# %% [markdown]
# <h3>Baseline model with 3 VGG blocks without dropout</h3>

# %%
# Define CNN model with three VGG-style blocks according to the principle explained earlier
def baseline_model_3():
    #reset_random_seeds()
    model = Sequential()
# 1st block    
    model.add(Conv2D(32, (3, 3), activation='relu', 
                     kernel_initializer='he_uniform', 
                     padding='same', input_shape=(img_rows, img_cols, 3)))
    model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
# 2d block    
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(64,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
# 3d block
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(128,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
   
    model.add(Flatten())
    model.add(Dense(128, activation='relu', 
                    kernel_initializer='he_uniform'))
    model.add(Dense(6, activation='softmax'))
# Compilation of a model
    opt = SGD(lr=0.001, momentum=0.9) # Gradient descent (with momentum) optimizer.
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# The model will be fit for 20 epochs - to check if the model can learn the problem.
# Define model
model = baseline_model_3()
# Fit model
history = model.fit_generator(training_set, steps_per_epoch=len(training_set),
                              validation_data=test_set, 
                              validation_steps=len(test_set), 
                              epochs= 25)
# Out:
# Epoch 1/25
# 53/53 [==============================] - 120s 2s/step - loss: 1.8064 - accuracy: 0.2054 - val_loss: 1.6606 - val_accuracy: 0.3118
# Epoch 2/25
# 53/53 [==============================] - 121s 2s/step - loss: 1.5919 - accuracy: 0.3569 - val_loss: 1.5015 - val_accuracy: 0.4056
# Epoch 3/25
# 53/53 [==============================] - 119s 2s/step - loss: 1.4809 - accuracy: 0.4258 - val_loss: 1.3783 - val_accuracy: 0.4646
# Epoch 4/25
# 53/53 [==============================] - 119s 2s/step - loss: 1.3954 - accuracy: 0.4787 - val_loss: 1.3719 - val_accuracy: 0.4819
# Epoch 5/25
# 53/53 [==============================] - 119s 2s/step - loss: 1.2992 - accuracy: 0.5075 - val_loss: 1.3322 - val_accuracy: 0.4958
# Epoch 6/25
# 53/53 [==============================] - 117s 2s/step - loss: 1.2359 - accuracy: 0.5437 - val_loss: 1.4353 - val_accuracy: 0.4549
# Epoch 7/25
# 53/53 [==============================] - 119s 2s/step - loss: 1.3134 - accuracy: 0.5079 - val_loss: 1.3522 - val_accuracy: 0.4958
# Epoch 8/25
# 53/53 [==============================] - 118s 2s/step - loss: 1.1262 - accuracy: 0.5872 - val_loss: 1.2441 - val_accuracy: 0.5451
# Epoch 9/25
# 53/53 [==============================] - 116s 2s/step - loss: 1.0679 - accuracy: 0.6059 - val_loss: 1.2516 - val_accuracy: 0.5514
# Epoch 10/25
# 53/53 [==============================] - 118s 2s/step - loss: 1.0404 - accuracy: 0.6313 - val_loss: 1.2883 - val_accuracy: 0.5319
# Epoch 11/25
# 53/53 [==============================] - 116s 2s/step - loss: 0.9371 - accuracy: 0.6650 - val_loss: 1.2161 - val_accuracy: 0.5597
# Epoch 12/25
# 53/53 [==============================] - 115s 2s/step - loss: 0.9409 - accuracy: 0.6543 - val_loss: 1.2364 - val_accuracy: 0.5493
# Epoch 13/25
# 53/53 [==============================] - 126s 2s/step - loss: 0.8436 - accuracy: 0.7045 - val_loss: 1.2151 - val_accuracy: 0.5597
# Epoch 14/25
# 53/53 [==============================] - 117s 2s/step - loss: 0.7112 - accuracy: 0.7593 - val_loss: 1.4060 - val_accuracy: 0.5090
# Epoch 15/25
# 53/53 [==============================] - 116s 2s/step - loss: 0.6563 - accuracy: 0.7687 - val_loss: 1.3246 - val_accuracy: 0.5306
# Epoch 16/25
# 53/53 [==============================] - 118s 2s/step - loss: 0.6167 - accuracy: 0.7803 - val_loss: 1.3338 - val_accuracy: 0.5604
# Epoch 17/25
# 53/53 [==============================] - 118s 2s/step - loss: 0.4824 - accuracy: 0.8389 - val_loss: 1.3627 - val_accuracy: 0.5431
# Epoch 18/25
# 53/53 [==============================] - 125s 2s/step - loss: 0.4325 - accuracy: 0.8598 - val_loss: 1.9706 - val_accuracy: 0.4500
# Epoch 19/25
# 53/53 [==============================] - 121s 2s/step - loss: 0.3978 - accuracy: 0.8671 - val_loss: 1.6956 - val_accuracy: 0.5417
# Epoch 20/25
# 53/53 [==============================] - 117s 2s/step - loss: 0.2711 - accuracy: 0.9117 - val_loss: 1.7053 - val_accuracy: 0.5389
# Epoch 21/25
# 53/53 [==============================] - 120s 2s/step - loss: 0.2072 - accuracy: 0.9409 - val_loss: 1.7384 - val_accuracy: 0.5681
# Epoch 22/25
# 53/53 [==============================] - 119s 2s/step - loss: 0.1214 - accuracy: 0.9683 - val_loss: 1.8976 - val_accuracy: 0.5472
# Epoch 23/25
# 53/53 [==============================] - 118s 2s/step - loss: 0.0712 - accuracy: 0.9876 - val_loss: 1.9965 - val_accuracy: 0.5562
# Epoch 24/25
# 53/53 [==============================] - 119s 2s/step - loss: 0.0526 - accuracy: 0.9940 - val_loss: 2.0571 - val_accuracy: 0.5493
# Epoch 25/25
# 53/53 [==============================] - 119s 2s/step - loss: 0.0311 - accuracy: 0.9951 - val_loss: 2.3169 - val_accuracy: 0.5535

# %%
# Evaluate model
_, acc = model.evaluate_generator(test_set, steps=len(test_set), verbose=0)
print("Accuracy: %.4f" % (acc * 100.0))
# Out:
# Accuracy: 55.3472

# %%
# Build graphs of entropy loss and accuracy
graph_accuracy_loss(history)

# %%
# Build a classification report
class_report(test_set, model)
# Out:
# Confusion Matrix
# [[151  16  12  32  15  14]
#  [ 17 148  25  14   8  28]
#  [ 23  26 120  22   5  44]
#  [ 19  13   9 167  11  21]
#  [ 41  19  12  58  88  22]
#  [ 24  25  29  29  10 123]]
# Classification Report
#               precision    recall  f1-score   support
#
#      Matisse       0.55      0.63      0.59       240
#        Monet       0.60      0.62      0.61       240
#      Pissaro       0.58      0.50      0.54       240
#       Renoir       0.52      0.70      0.59       240
#      Sargent       0.64      0.37      0.47       240
#      VanGogh       0.49      0.51      0.50       240
#
#     accuracy                           0.55      1440
#    macro avg       0.56      0.55      0.55      1440
# weighted avg       0.56      0.55      0.55      1440

# %%
# Accuracy score for 3 VGG blocks is higher than for 2 vgg blcoks model, 
# so we will continiue with it.
# We still have an over-fitting so we will add a dropout regularizatiom

# %%
# Part 2 - Add Dropout Regularization and Data Augmentation
# to our Baseline model step by step and evaluate an efficiency  
# ___________________________________________________________


# 1 step - Add Dropout

# %% [markdown]
# <h3>Model with 3 VGG blocks with dropout</h3>

# %%
# Prepare the data. Instanciate ImageDataGenerator that scalse the pixel values to the range of 0-1
# We don't use data augmentation for this moment 
datagen = ImageDataGenerator(rescale=1. / 255)

training_set = datagen.flow_from_directory('train', target_size=(img_rows, img_cols),
                                                 batch_size=batch_size,
                                                 class_mode='categorical')

test_set = datagen.flow_from_directory('val',target_size=(img_rows, img_cols),
                                            batch_size=batch_size, shuffle = False,
                                            class_mode='categorical')
# Out:
# Found 3360 images belonging to 6 classes.
# Found 1440 images belonging to 6 classes.

# %%
# Define CNN model with Dropout Regularization using 3 VGG blocks model
def model_with_dropout():
    model = Sequential()
   
    # 1st block    
    model.add(Conv2D(32, (3, 3), activation='relu', 
                     kernel_initializer='he_uniform', 
                     padding='same', input_shape=(img_rows, img_cols, 3)))
    model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    
# 2d block    
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(64,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    
# 3d block
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(128,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
   
    model.add(Flatten())
    model.add(Dense(128, activation='relu', 
                    kernel_initializer='he_uniform'))
# Dropout 0.5 was added meaning that 50% of the nodes will be ignored
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='softmax'))
    # Compilation of a model
    opt = SGD(lr=0.001, momentum=0.9) # Gradient descent (with momentum) optimizer.
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# The model will be fit for 30 epochs 
# Define model
model_d = model_with_dropout()
# Fit model
history = model_d.fit_generator(training_set, steps_per_epoch=len(training_set),
                                validation_data=test_set,
                                validation_steps=len(test_set), 
                                epochs= epochs)
# Out:
# Epoch 1/30
# 53/53 [==============================] - 44s 178ms/step - loss: 1.8069 - accuracy: 0.2356 - val_loss: 1.5814 - val_accuracy: 0.4000
# Epoch 2/30
# 53/53 [==============================] - 8s 150ms/step - loss: 1.6245 - accuracy: 0.3408 - val_loss: 1.4526 - val_accuracy: 0.4563
# Epoch 3/30
# 53/53 [==============================] - 8s 148ms/step - loss: 1.5109 - accuracy: 0.4194 - val_loss: 1.4159 - val_accuracy: 0.4854
# Epoch 4/30
# 53/53 [==============================] - 8s 147ms/step - loss: 1.5126 - accuracy: 0.4131 - val_loss: 1.4531 - val_accuracy: 0.4625
# Epoch 5/30
# 53/53 [==============================] - 8s 148ms/step - loss: 1.4632 - accuracy: 0.4358 - val_loss: 1.3955 - val_accuracy: 0.4694
# Epoch 6/30
# 53/53 [==============================] - 8s 148ms/step - loss: 1.4167 - accuracy: 0.4476 - val_loss: 1.3418 - val_accuracy: 0.4965
# Epoch 7/30
# 53/53 [==============================] - 8s 155ms/step - loss: 1.3404 - accuracy: 0.4911 - val_loss: 1.3372 - val_accuracy: 0.5097
# Epoch 8/30
# 53/53 [==============================] - 8s 149ms/step - loss: 1.3194 - accuracy: 0.4947 - val_loss: 1.2977 - val_accuracy: 0.5118
# Epoch 9/30
# 53/53 [==============================] - 8s 148ms/step - loss: 1.2612 - accuracy: 0.5297 - val_loss: 1.2469 - val_accuracy: 0.5472
# Epoch 10/30
# 53/53 [==============================] - 8s 150ms/step - loss: 1.2031 - accuracy: 0.5397 - val_loss: 1.2271 - val_accuracy: 0.5528
# Epoch 11/30
# 53/53 [==============================] - 8s 156ms/step - loss: 1.1543 - accuracy: 0.5653 - val_loss: 1.2334 - val_accuracy: 0.5292
# Epoch 12/30
# 53/53 [==============================] - 8s 154ms/step - loss: 1.1454 - accuracy: 0.5837 - val_loss: 1.3610 - val_accuracy: 0.4736
# Epoch 13/30
# 53/53 [==============================] - 8s 152ms/step - loss: 1.1502 - accuracy: 0.5754 - val_loss: 1.2455 - val_accuracy: 0.5431
# Epoch 14/30
# 53/53 [==============================] - 8s 154ms/step - loss: 1.0681 - accuracy: 0.6055 - val_loss: 1.2099 - val_accuracy: 0.5417
# Epoch 15/30
# 53/53 [==============================] - 8s 154ms/step - loss: 1.0431 - accuracy: 0.6251 - val_loss: 1.2222 - val_accuracy: 0.5465
# Epoch 16/30
# 53/53 [==============================] - 8s 154ms/step - loss: 1.0280 - accuracy: 0.6349 - val_loss: 1.2211 - val_accuracy: 0.5535
# Epoch 17/30
# 53/53 [==============================] - 8s 154ms/step - loss: 0.9911 - accuracy: 0.6417 - val_loss: 1.1762 - val_accuracy: 0.5639
# Epoch 18/30
# 53/53 [==============================] - 8s 149ms/step - loss: 0.9654 - accuracy: 0.6511 - val_loss: 1.1616 - val_accuracy: 0.5674
# Epoch 19/30
# 53/53 [==============================] - 8s 150ms/step - loss: 0.9336 - accuracy: 0.6576 - val_loss: 1.1787 - val_accuracy: 0.5681
# Epoch 20/30
# 53/53 [==============================] - 8s 150ms/step - loss: 0.8365 - accuracy: 0.6895 - val_loss: 1.1662 - val_accuracy: 0.5764
# Epoch 21/30
# 53/53 [==============================] - 8s 151ms/step - loss: 0.8403 - accuracy: 0.6904 - val_loss: 1.1987 - val_accuracy: 0.5806
# Epoch 22/30
# 53/53 [==============================] - 8s 153ms/step - loss: 0.7599 - accuracy: 0.7195 - val_loss: 1.3464 - val_accuracy: 0.5361
# Epoch 23/30
# 53/53 [==============================] - 8s 150ms/step - loss: 0.7777 - accuracy: 0.7109 - val_loss: 1.3389 - val_accuracy: 0.5326
# Epoch 24/30
# 53/53 [==============================] - 8s 150ms/step - loss: 0.6631 - accuracy: 0.7636 - val_loss: 1.2063 - val_accuracy: 0.5778
# Epoch 25/30
# 53/53 [==============================] - 8s 148ms/step - loss: 0.5631 - accuracy: 0.7896 - val_loss: 1.2196 - val_accuracy: 0.6007
# Epoch 26/30
# 53/53 [==============================] - 8s 149ms/step - loss: 0.5827 - accuracy: 0.8019 - val_loss: 1.3610 - val_accuracy: 0.5431
# Epoch 27/30
# 53/53 [==============================] - 8s 151ms/step - loss: 0.5764 - accuracy: 0.8057 - val_loss: 1.3045 - val_accuracy: 0.5715
# Epoch 28/30
# 53/53 [==============================] - 8s 150ms/step - loss: 0.4460 - accuracy: 0.8353 - val_loss: 1.2717 - val_accuracy: 0.5875
# Epoch 29/30
# 53/53 [==============================] - 8s 150ms/step - loss: 0.4211 - accuracy: 0.8581 - val_loss: 1.3231 - val_accuracy: 0.5688
# Epoch 30/30
# 53/53 [==============================] - 8s 149ms/step - loss: 0.4064 - accuracy: 0.8616 - val_loss: 1.4435 - val_accuracy: 0.5792

# %%
# Evaluate model
_, acc = model_d.evaluate_generator(test_set, steps=len(test_set), verbose=0)
print("Accuracy: %.4f" % (acc * 100.0))
# Out:
# Accuracy: 57.9167

# %%
# Build graphs of entropy loss and accuracy
graph_accuracy_loss(history)

# %%
# As we see model overfitts less after usage of dropout

# %%
# Build a classification report
class_report(test_set, model_d)
# Out:
# Confusion Matrix
# [[178   7   8  10  24  13]
#  [ 19 144  33   9  19  16]
#  [ 16  28 142  19  14  21]
#  [ 21  17  22 145  23  12]
#  [ 50   8   9  25 138  10]
#  [ 21  24  36  13  28 118]]
# Classification Report
#               precision    recall  f1-score   support
#
#      Matisse       0.58      0.74      0.65       240
#        Monet       0.63      0.60      0.62       240
#      Pissaro       0.57      0.59      0.58       240
#       Renoir       0.66      0.60      0.63       240
#      Sargent       0.56      0.57      0.57       240
#      VanGogh       0.62      0.49      0.55       240
#
#     accuracy                           0.60      1440
#    macro avg       0.60      0.60      0.60      1440
# weighted avg       0.60      0.60      0.60      1440

# %%
# 2 step - Add Data augmentation
# Use our 3 VGG blocks model with dropout

# %% [markdown]
# <h3>Model with 3 VGG blocks with dropout and data augmentation</h3>

# %% [markdown]
# <h4>Trained for max 85 epochs with dropout and data augmentation (with Early Stopping and saving the best model)</h4>

# %%
# Implementing Early stoping and checkpoint to save the model with the highest accuracy
ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
# Save chekpoints to best_model.h5
MC = ModelCheckpoint('best_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, 
                     save_weights_only=False, mode='auto')

# %%
# Before implementing data augmentation, will look how its afect the image

# %%
# Print a random paintings and augmented version
fig, axes = plt.subplots(1, 2, figsize=(10,10))

# Select a random artist
random_artist = random.choice(artists_name)
# Select a random image with selected random artist
random_image = random.choice(os.listdir(os.path.join('train', random_artist)))
# Get the direction of image file
random_image_file = os.path.join('train', random_artist, random_image)

# Original image
image = plt.imread(random_image_file)
axes[0].imshow(image)
axes[0].set_title("Original Image of " + random_artist.replace('_', ' '))
axes[0].axis('off')

# Transformed image
aug_image = datagen.apply_transform(image,
                                    transform_parameters={#'theta': ,
                                                          #'tx':,
                                                          #'ty': ,
                                                          #'shear': ,
                                                          #'zx': ,
                                                          #'zy': ,
                                                          #'flip_horizontal': True,
                                                          'flip_vertical': True,
                                                          #'channel_shift_intensity': ,
                                                          #'brightness':
                                                         })
axes[1].imshow(aug_image)
axes[1].set_title("Transformed Image of " + random_artist.replace('_', ' '))
axes[1].axis('off')

plt.show()

# %%
# Create data generators with data augmentation (different zooming, horizontal flip and shear intensity)
train_datagen = ImageDataGenerator(rescale=1. / 255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   fill_mode='nearest')
# We do not use data augmentation for test dataset, only normalize pixels
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Create sets
training_set = train_datagen.flow_from_directory('train',
                                                 target_size=(img_rows, img_cols),
                                                 batch_size=batch_size,
                                                 class_mode='categorical')


test_set = test_datagen.flow_from_directory('val',
                                            target_size=(img_rows, img_cols),
                                            batch_size=batch_size, shuffle = False,
                                            class_mode='categorical')

# Define model
model_dropout_dataaugm = model_with_dropout()
# Fit model
history = model_dropout_dataaugm.fit_generator(training_set, 
                              steps_per_epoch=len(training_set),
                              validation_data=test_set, 
                              validation_steps=len(test_set), 
                              epochs= 85, callbacks=[ES, MC])
# Out:
# Found 3360 images belonging to 6 classes.
# Found 1440 images belonging to 6 classes.
# Epoch 1/85
# 53/53 [==============================] - 19s 343ms/step - loss: 1.9072 - accuracy: 0.1760 - val_loss: 1.7420 - val_accuracy: 0.3326
#
# Epoch 00001: val_accuracy improved from -inf to 0.33264, saving model to best_model.h5
# Epoch 2/85
# 53/53 [==============================] - 18s 340ms/step - loss: 1.7360 - accuracy: 0.2781 - val_loss: 1.6481 - val_accuracy: 0.3833
#
# Epoch 00002: val_accuracy improved from 0.33264 to 0.38333, saving model to best_model.h5
# Epoch 3/85
# 53/53 [==============================] - 18s 334ms/step - loss: 1.6649 - accuracy: 0.3283 - val_loss: 1.5779 - val_accuracy: 0.4153
#
# Epoch 00003: val_accuracy improved from 0.38333 to 0.41528, saving model to best_model.h5
# Epoch 4/85
# 53/53 [==============================] - 18s 337ms/step - loss: 1.5980 - accuracy: 0.3755 - val_loss: 1.4965 - val_accuracy: 0.4306
#
# Epoch 00004: val_accuracy improved from 0.41528 to 0.43056, saving model to best_model.h5
# Epoch 5/85
# 53/53 [==============================] - 18s 337ms/step - loss: 1.5788 - accuracy: 0.3743 - val_loss: 1.4420 - val_accuracy: 0.4569
#
# Epoch 00005: val_accuracy improved from 0.43056 to 0.45694, saving model to best_model.h5
# Epoch 6/85
# 53/53 [==============================] - 18s 340ms/step - loss: 1.6195 - accuracy: 0.3395 - val_loss: 1.5588 - val_accuracy: 0.3972
#
# Epoch 00006: val_accuracy did not improve from 0.45694
# Epoch 7/85
# 53/53 [==============================] - 18s 335ms/step - loss: 1.5455 - accuracy: 0.3962 - val_loss: 1.4899 - val_accuracy: 0.4417
#
# Epoch 00007: val_accuracy did not improve from 0.45694
# Epoch 8/85
# 53/53 [==============================] - 18s 339ms/step - loss: 1.5456 - accuracy: 0.4004 - val_loss: 1.4143 - val_accuracy: 0.4736
#
# Epoch 00008: val_accuracy improved from 0.45694 to 0.47361, saving model to best_model.h5
# Epoch 9/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.5148 - accuracy: 0.4018 - val_loss: 1.3931 - val_accuracy: 0.4896
#
# Epoch 00009: val_accuracy improved from 0.47361 to 0.48958, saving model to best_model.h5
# Epoch 10/85
# 53/53 [==============================] - 18s 335ms/step - loss: 1.4633 - accuracy: 0.4347 - val_loss: 1.4170 - val_accuracy: 0.4625
#
# Epoch 00010: val_accuracy did not improve from 0.48958
# Epoch 11/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.4495 - accuracy: 0.4413 - val_loss: 1.3662 - val_accuracy: 0.4771
#
# Epoch 00011: val_accuracy did not improve from 0.48958
# Epoch 12/85
# 53/53 [==============================] - 18s 339ms/step - loss: 1.4455 - accuracy: 0.4368 - val_loss: 1.3260 - val_accuracy: 0.4993
#
# Epoch 00012: val_accuracy improved from 0.48958 to 0.49931, saving model to best_model.h5
# Epoch 13/85
# 53/53 [==============================] - 18s 340ms/step - loss: 1.4252 - accuracy: 0.4474 - val_loss: 1.3518 - val_accuracy: 0.4861
#
# Epoch 00013: val_accuracy did not improve from 0.49931
# Epoch 14/85
# 53/53 [==============================] - 18s 336ms/step - loss: 1.3806 - accuracy: 0.4843 - val_loss: 1.3425 - val_accuracy: 0.5125
#
# Epoch 00014: val_accuracy improved from 0.49931 to 0.51250, saving model to best_model.h5
# Epoch 15/85
# 53/53 [==============================] - 18s 345ms/step - loss: 1.3751 - accuracy: 0.4820 - val_loss: 1.3203 - val_accuracy: 0.5021
#
# Epoch 00015: val_accuracy did not improve from 0.51250
# Epoch 16/85
# 53/53 [==============================] - 18s 336ms/step - loss: 1.3490 - accuracy: 0.5004 - val_loss: 1.2186 - val_accuracy: 0.5556
#
# Epoch 00016: val_accuracy improved from 0.51250 to 0.55556, saving model to best_model.h5
# Epoch 17/85
# 53/53 [==============================] - 18s 343ms/step - loss: 1.3181 - accuracy: 0.4985 - val_loss: 1.2818 - val_accuracy: 0.5174
#
# Epoch 00017: val_accuracy did not improve from 0.55556
# Epoch 18/85
# 53/53 [==============================] - 18s 343ms/step - loss: 1.3292 - accuracy: 0.5028 - val_loss: 1.2811 - val_accuracy: 0.5083
#
# Epoch 00018: val_accuracy did not improve from 0.55556
# Epoch 19/85
# 53/53 [==============================] - 18s 341ms/step - loss: 1.3366 - accuracy: 0.5009 - val_loss: 1.2235 - val_accuracy: 0.5604
#
# Epoch 00019: val_accuracy improved from 0.55556 to 0.56042, saving model to best_model.h5
# Epoch 20/85
# 53/53 [==============================] - 18s 342ms/step - loss: 1.2975 - accuracy: 0.5136 - val_loss: 1.2577 - val_accuracy: 0.5278
#
# Epoch 00020: val_accuracy did not improve from 0.56042
# Epoch 21/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.2480 - accuracy: 0.5192 - val_loss: 1.1747 - val_accuracy: 0.5743
#
# Epoch 00021: val_accuracy improved from 0.56042 to 0.57431, saving model to best_model.h5
# Epoch 22/85
# 53/53 [==============================] - 18s 341ms/step - loss: 1.2050 - accuracy: 0.5566 - val_loss: 1.2159 - val_accuracy: 0.5632
#
# Epoch 00022: val_accuracy did not improve from 0.57431
# Epoch 23/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.2890 - accuracy: 0.5220 - val_loss: 1.1945 - val_accuracy: 0.5611
#
# Epoch 00023: val_accuracy did not improve from 0.57431
# Epoch 24/85
# 53/53 [==============================] - 18s 340ms/step - loss: 1.1849 - accuracy: 0.5529 - val_loss: 1.2067 - val_accuracy: 0.5604
#
# Epoch 00024: val_accuracy did not improve from 0.57431
# Epoch 25/85
# 53/53 [==============================] - 18s 337ms/step - loss: 1.1874 - accuracy: 0.5679 - val_loss: 1.3015 - val_accuracy: 0.5181
#
# Epoch 00025: val_accuracy did not improve from 0.57431
# Epoch 26/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.1730 - accuracy: 0.5632 - val_loss: 1.1372 - val_accuracy: 0.5868
#
# Epoch 00026: val_accuracy improved from 0.57431 to 0.58681, saving model to best_model.h5
# Epoch 27/85
# 53/53 [==============================] - 18s 339ms/step - loss: 1.1870 - accuracy: 0.5519 - val_loss: 1.2622 - val_accuracy: 0.5250
#
# Epoch 00027: val_accuracy did not improve from 0.58681
# Epoch 28/85
# 53/53 [==============================] - 18s 340ms/step - loss: 1.1786 - accuracy: 0.5647 - val_loss: 1.1695 - val_accuracy: 0.5708
#
# Epoch 00028: val_accuracy did not improve from 0.58681
# Epoch 29/85
# 53/53 [==============================] - 18s 340ms/step - loss: 1.1461 - accuracy: 0.5749 - val_loss: 1.2023 - val_accuracy: 0.5604
#
# Epoch 00029: val_accuracy did not improve from 0.58681
# Epoch 30/85
# 53/53 [==============================] - 18s 335ms/step - loss: 1.1171 - accuracy: 0.5953 - val_loss: 1.1396 - val_accuracy: 0.5958
#
# Epoch 00030: val_accuracy improved from 0.58681 to 0.59583, saving model to best_model.h5
# Epoch 31/85
# 53/53 [==============================] - 18s 341ms/step - loss: 1.1168 - accuracy: 0.5841 - val_loss: 1.3096 - val_accuracy: 0.5236
#
# Epoch 00031: val_accuracy did not improve from 0.59583
# Epoch 32/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.1117 - accuracy: 0.5864 - val_loss: 1.1355 - val_accuracy: 0.5903
#
# Epoch 00032: val_accuracy did not improve from 0.59583
# Epoch 33/85
# 53/53 [==============================] - 18s 339ms/step - loss: 1.1255 - accuracy: 0.5658 - val_loss: 1.1486 - val_accuracy: 0.5639
#
# Epoch 00033: val_accuracy did not improve from 0.59583
# Epoch 34/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.0785 - accuracy: 0.5935 - val_loss: 1.1039 - val_accuracy: 0.5986
#
# Epoch 00034: val_accuracy improved from 0.59583 to 0.59861, saving model to best_model.h5
# Epoch 35/85
# 53/53 [==============================] - 18s 346ms/step - loss: 1.0470 - accuracy: 0.6198 - val_loss: 1.0520 - val_accuracy: 0.6132
#
# Epoch 00035: val_accuracy improved from 0.59861 to 0.61319, saving model to best_model.h5
# Epoch 36/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.0721 - accuracy: 0.6199 - val_loss: 1.1248 - val_accuracy: 0.5896
#
# Epoch 00036: val_accuracy did not improve from 0.61319
# Epoch 37/85
# 53/53 [==============================] - 18s 341ms/step - loss: 1.0706 - accuracy: 0.5937 - val_loss: 1.1090 - val_accuracy: 0.6056
#
# Epoch 00037: val_accuracy did not improve from 0.61319
# Epoch 38/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.0627 - accuracy: 0.6112 - val_loss: 1.0528 - val_accuracy: 0.6056
#
# Epoch 00038: val_accuracy did not improve from 0.61319
# Epoch 39/85
# 53/53 [==============================] - 18s 337ms/step - loss: 1.0195 - accuracy: 0.6266 - val_loss: 1.1601 - val_accuracy: 0.5819
#
# Epoch 00039: val_accuracy did not improve from 0.61319
# Epoch 40/85
# 53/53 [==============================] - 18s 341ms/step - loss: 0.9999 - accuracy: 0.6318 - val_loss: 1.0933 - val_accuracy: 0.6049
#
# Epoch 00040: val_accuracy did not improve from 0.61319
# Epoch 41/85
# 53/53 [==============================] - 18s 337ms/step - loss: 0.9632 - accuracy: 0.6602 - val_loss: 1.0635 - val_accuracy: 0.6250
#
# Epoch 00041: val_accuracy improved from 0.61319 to 0.62500, saving model to best_model.h5
# Epoch 42/85
# 53/53 [==============================] - 18s 342ms/step - loss: 0.9947 - accuracy: 0.6399 - val_loss: 1.0520 - val_accuracy: 0.6299
#
# Epoch 00042: val_accuracy improved from 0.62500 to 0.62986, saving model to best_model.h5
# Epoch 43/85
# 53/53 [==============================] - 18s 336ms/step - loss: 0.9824 - accuracy: 0.6455 - val_loss: 1.0972 - val_accuracy: 0.6069
#
# Epoch 00043: val_accuracy did not improve from 0.62986
# Epoch 44/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.9612 - accuracy: 0.6406 - val_loss: 1.2268 - val_accuracy: 0.5569
#
# Epoch 00044: val_accuracy did not improve from 0.62986
# Epoch 45/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.9447 - accuracy: 0.6649 - val_loss: 1.0741 - val_accuracy: 0.6083
#
# Epoch 00045: val_accuracy did not improve from 0.62986
# Epoch 46/85
# 53/53 [==============================] - 18s 344ms/step - loss: 0.9379 - accuracy: 0.6618 - val_loss: 1.0817 - val_accuracy: 0.6167
#
# Epoch 00046: val_accuracy did not improve from 0.62986
# Epoch 47/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.9436 - accuracy: 0.6621 - val_loss: 1.2758 - val_accuracy: 0.5535
#
# Epoch 00047: val_accuracy did not improve from 0.62986
# Epoch 48/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.9375 - accuracy: 0.6562 - val_loss: 1.1472 - val_accuracy: 0.5854
#
# Epoch 00048: val_accuracy did not improve from 0.62986
# Epoch 49/85
# 53/53 [==============================] - 18s 341ms/step - loss: 0.9100 - accuracy: 0.6700 - val_loss: 1.1549 - val_accuracy: 0.5771
#
# Epoch 00049: val_accuracy did not improve from 0.62986
# Epoch 50/85
# 53/53 [==============================] - 18s 336ms/step - loss: 0.9059 - accuracy: 0.6570 - val_loss: 1.1190 - val_accuracy: 0.6028
#
# Epoch 00050: val_accuracy did not improve from 0.62986
# Epoch 51/85
# 53/53 [==============================] - 18s 344ms/step - loss: 0.8982 - accuracy: 0.6660 - val_loss: 1.1917 - val_accuracy: 0.5757
#
# Epoch 00051: val_accuracy did not improve from 0.62986
# Epoch 52/85
# 53/53 [==============================] - 18s 343ms/step - loss: 0.8807 - accuracy: 0.6860 - val_loss: 1.0088 - val_accuracy: 0.6396
#
# Epoch 00052: val_accuracy improved from 0.62986 to 0.63958, saving model to best_model.h5
# Epoch 53/85
# 53/53 [==============================] - 18s 341ms/step - loss: 0.9466 - accuracy: 0.6498 - val_loss: 1.1313 - val_accuracy: 0.6035
#
# Epoch 00053: val_accuracy did not improve from 0.63958
# Epoch 54/85
# 53/53 [==============================] - 18s 337ms/step - loss: 0.8828 - accuracy: 0.6647 - val_loss: 1.0713 - val_accuracy: 0.6319
#
# Epoch 00054: val_accuracy did not improve from 0.63958
# Epoch 55/85
# 53/53 [==============================] - 18s 342ms/step - loss: 0.8388 - accuracy: 0.6878 - val_loss: 1.2654 - val_accuracy: 0.5653
#
# Epoch 00055: val_accuracy did not improve from 0.63958
# Epoch 56/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.8546 - accuracy: 0.6888 - val_loss: 1.1594 - val_accuracy: 0.5924
#
# Epoch 00056: val_accuracy did not improve from 0.63958
# Epoch 57/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.7863 - accuracy: 0.7169 - val_loss: 1.0331 - val_accuracy: 0.6319
#
# Epoch 00057: val_accuracy did not improve from 0.63958
# Epoch 58/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.8254 - accuracy: 0.6892 - val_loss: 1.3312 - val_accuracy: 0.5576
#
# Epoch 00058: val_accuracy did not improve from 0.63958
# Epoch 59/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.8356 - accuracy: 0.6890 - val_loss: 1.4229 - val_accuracy: 0.5583
#
# Epoch 00059: val_accuracy did not improve from 0.63958
# Epoch 60/85
# 53/53 [==============================] - 18s 342ms/step - loss: 0.8129 - accuracy: 0.6932 - val_loss: 1.2248 - val_accuracy: 0.5889
#
# Epoch 00060: val_accuracy did not improve from 0.63958
# Epoch 61/85
# 53/53 [==============================] - 18s 337ms/step - loss: 0.8143 - accuracy: 0.6972 - val_loss: 1.1128 - val_accuracy: 0.6097
#
# Epoch 00061: val_accuracy did not improve from 0.63958
# Epoch 62/85
# 53/53 [==============================] - 18s 341ms/step - loss: 0.7751 - accuracy: 0.7049 - val_loss: 1.1337 - val_accuracy: 0.6035
#
# Epoch 00062: val_accuracy did not improve from 0.63958
# Epoch 63/85
# 53/53 [==============================] - 18s 336ms/step - loss: 0.8116 - accuracy: 0.7034 - val_loss: 1.0656 - val_accuracy: 0.6236
#
# Epoch 00063: val_accuracy did not improve from 0.63958
# Epoch 64/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.7318 - accuracy: 0.7407 - val_loss: 1.1286 - val_accuracy: 0.6194
#
# Epoch 00064: val_accuracy did not improve from 0.63958
# Epoch 65/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.7316 - accuracy: 0.7247 - val_loss: 1.1700 - val_accuracy: 0.6201
#
# Epoch 00065: val_accuracy did not improve from 0.63958
# Epoch 66/85
# 53/53 [==============================] - 18s 341ms/step - loss: 0.7416 - accuracy: 0.7252 - val_loss: 1.2428 - val_accuracy: 0.6049
#
# Epoch 00066: val_accuracy did not improve from 0.63958
# Epoch 67/85
# 53/53 [==============================] - 18s 339ms/step - loss: 0.7432 - accuracy: 0.7362 - val_loss: 1.1149 - val_accuracy: 0.6229
#
# Epoch 00067: val_accuracy did not improve from 0.63958
# Epoch 68/85
# 53/53 [==============================] - 18s 344ms/step - loss: 0.7399 - accuracy: 0.7277 - val_loss: 1.1135 - val_accuracy: 0.6389
#
# Epoch 00068: val_accuracy did not improve from 0.63958
# Epoch 69/85
# 53/53 [==============================] - 18s 344ms/step - loss: 0.6732 - accuracy: 0.7465 - val_loss: 1.1423 - val_accuracy: 0.6076
#
# Epoch 00069: val_accuracy did not improve from 0.63958
# Epoch 70/85
# 53/53 [==============================] - 18s 341ms/step - loss: 0.6815 - accuracy: 0.7557 - val_loss: 1.2210 - val_accuracy: 0.6007
#
# Epoch 00070: val_accuracy did not improve from 0.63958
# Epoch 71/85
# 53/53 [==============================] - 18s 342ms/step - loss: 0.6865 - accuracy: 0.7494 - val_loss: 1.4578 - val_accuracy: 0.5556
#
# Epoch 00071: val_accuracy did not improve from 0.63958
# Epoch 72/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.7043 - accuracy: 0.7408 - val_loss: 1.1752 - val_accuracy: 0.6229
#
# Epoch 00072: val_accuracy did not improve from 0.63958
# Epoch 00072: early stopping

# %%
# Create a new model instance to upload the best saved model there
# because our trained model finished training with the final accuracy not the best possible
model_best = model_with_dropout()


model_best.load_weights('best_model.h5')
# Evaluate model

_, acc = model_best.evaluate_generator(test_set, steps=len(test_set), verbose=0)
print("Best accuracy: %.4f" % (acc * 100.0))
# Out:
# Best accuracy: 63.9583

# %%
# Build graphs of entropy loss and accuracy
graph_accuracy_loss(history)

# %% [markdown]
# <h4>Trained for max 85 epochs and bigger size of pictures (224*224px instead 128*128px) and Early Stopping</h4>

# %%
# Implementing Early stoping and checkpoint to save the model with the highest accuracy
ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
# Save chekpoints to best_model_224px.h5
MC = ModelCheckpoint('best_model_224px.h5', monitor='val_accuracy', verbose=1, save_best_only=True, 
                     save_weights_only=False, mode='auto')

# %%
# Let's try to change pictures size from 128 to 224px and check accuracy
# Create data generators according to the principle as before
train_datagen = ImageDataGenerator(rescale=1. / 255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   fill_mode='nearest')
# We do not use data augmentation for test dataset, only normalize pixels
test_datagen = ImageDataGenerator(rescale=1. / 255)

img_rows = 224
img_cols = 224
# Create sets
training_set = train_datagen.flow_from_directory('train',
                                                 target_size=(img_rows, img_cols),
                                                 batch_size=batch_size,
                                                 class_mode='categorical')


test_set = test_datagen.flow_from_directory('val',
                                            target_size=(img_rows, img_cols),
                                            batch_size=batch_size, shuffle = False,
                                            class_mode='categorical')

# Define model
model224 = model_with_dropout()
# Fit model
history = model224.fit_generator(training_set, 
                              steps_per_epoch=len(training_set),
                              validation_data=test_set, 
                              validation_steps=len(test_set), 
                              epochs= 85, callbacks=[ES, MC])
# Out:
# Found 3360 images belonging to 6 classes.
# Found 1440 images belonging to 6 classes.
# Epoch 1/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.8328 - accuracy: 0.2140 - val_loss: 1.6944 - val_accuracy: 0.2639
#
# Epoch 00001: val_accuracy improved from -inf to 0.26389, saving model to best_model_224px.h5
# Epoch 2/85
# 53/53 [==============================] - 328s 6s/step - loss: 1.6909 - accuracy: 0.2965 - val_loss: 1.5895 - val_accuracy: 0.3778
#
# Epoch 00002: val_accuracy improved from 0.26389 to 0.37778, saving model to best_model_224px.h5
# Epoch 3/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.6376 - accuracy: 0.3441 - val_loss: 1.5510 - val_accuracy: 0.4111
#
# Epoch 00003: val_accuracy improved from 0.37778 to 0.41111, saving model to best_model_224px.h5
# Epoch 4/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.6085 - accuracy: 0.3495 - val_loss: 1.4963 - val_accuracy: 0.4500
#
# Epoch 00004: val_accuracy improved from 0.41111 to 0.45000, saving model to best_model_224px.h5
# Epoch 5/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.5581 - accuracy: 0.3743 - val_loss: 1.4736 - val_accuracy: 0.4556
#
# Epoch 00005: val_accuracy improved from 0.45000 to 0.45556, saving model to best_model_224px.h5
# Epoch 6/85
# 53/53 [==============================] - 328s 6s/step - loss: 1.5056 - accuracy: 0.4185 - val_loss: 1.4650 - val_accuracy: 0.4799
#
# Epoch 00006: val_accuracy improved from 0.45556 to 0.47986, saving model to best_model_224px.h5
# Epoch 7/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.5136 - accuracy: 0.4116 - val_loss: 1.4462 - val_accuracy: 0.4549
#
# Epoch 00007: val_accuracy did not improve from 0.47986
# Epoch 8/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.4836 - accuracy: 0.4199 - val_loss: 1.3893 - val_accuracy: 0.4847
#
# Epoch 00008: val_accuracy improved from 0.47986 to 0.48472, saving model to best_model_224px.h5
# Epoch 9/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.4576 - accuracy: 0.4357 - val_loss: 1.3494 - val_accuracy: 0.5090
#
# Epoch 00009: val_accuracy improved from 0.48472 to 0.50903, saving model to best_model_224px.h5
# Epoch 10/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.4277 - accuracy: 0.4421 - val_loss: 1.3866 - val_accuracy: 0.4847
#
# Epoch 00010: val_accuracy did not improve from 0.50903
# Epoch 11/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.3909 - accuracy: 0.4737 - val_loss: 1.2611 - val_accuracy: 0.5222
#
# Epoch 00011: val_accuracy improved from 0.50903 to 0.52222, saving model to best_model_224px.h5
# Epoch 12/85
# 53/53 [==============================] - 328s 6s/step - loss: 1.3298 - accuracy: 0.4888 - val_loss: 1.2909 - val_accuracy: 0.5257
#
# Epoch 00012: val_accuracy improved from 0.52222 to 0.52569, saving model to best_model_224px.h5
# Epoch 13/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.3429 - accuracy: 0.4939 - val_loss: 1.2339 - val_accuracy: 0.5417
#
# Epoch 00013: val_accuracy improved from 0.52569 to 0.54167, saving model to best_model_224px.h5
# Epoch 14/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.3063 - accuracy: 0.4992 - val_loss: 1.2715 - val_accuracy: 0.5097
#
# Epoch 00014: val_accuracy did not improve from 0.54167
# Epoch 15/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.3283 - accuracy: 0.4929 - val_loss: 1.2455 - val_accuracy: 0.5375
#
# Epoch 00015: val_accuracy did not improve from 0.54167
# Epoch 16/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.2871 - accuracy: 0.5223 - val_loss: 1.2758 - val_accuracy: 0.5354
#
# Epoch 00016: val_accuracy did not improve from 0.54167
# Epoch 17/85
# 53/53 [==============================] - 328s 6s/step - loss: 1.2620 - accuracy: 0.5349 - val_loss: 1.2061 - val_accuracy: 0.5514
#
# Epoch 00017: val_accuracy improved from 0.54167 to 0.55139, saving model to best_model_224px.h5
# Epoch 18/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.2095 - accuracy: 0.5448 - val_loss: 1.1251 - val_accuracy: 0.6062
#
# Epoch 00018: val_accuracy improved from 0.55139 to 0.60625, saving model to best_model_224px.h5
# Epoch 19/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.1916 - accuracy: 0.5564 - val_loss: 1.1981 - val_accuracy: 0.5569
#
# Epoch 00019: val_accuracy did not improve from 0.60625
# Epoch 20/85
# 53/53 [==============================] - 328s 6s/step - loss: 1.1914 - accuracy: 0.5449 - val_loss: 1.1363 - val_accuracy: 0.5778
#
# Epoch 00020: val_accuracy did not improve from 0.60625
# Epoch 21/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.1629 - accuracy: 0.5780 - val_loss: 1.2119 - val_accuracy: 0.5458
#
# Epoch 00021: val_accuracy did not improve from 0.60625
# Epoch 22/85
# 53/53 [==============================] - 328s 6s/step - loss: 1.2278 - accuracy: 0.5500 - val_loss: 1.1160 - val_accuracy: 0.5951
#
# Epoch 00022: val_accuracy did not improve from 0.60625
# Epoch 23/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.1583 - accuracy: 0.5907 - val_loss: 1.0890 - val_accuracy: 0.6111
#
# Epoch 00023: val_accuracy improved from 0.60625 to 0.61111, saving model to best_model_224px.h5
# Epoch 24/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.0813 - accuracy: 0.6028 - val_loss: 1.1620 - val_accuracy: 0.5757
#
# Epoch 00024: val_accuracy did not improve from 0.61111
# Epoch 25/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.1143 - accuracy: 0.5856 - val_loss: 1.1554 - val_accuracy: 0.5917
#
# Epoch 00025: val_accuracy did not improve from 0.61111
# Epoch 26/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.0929 - accuracy: 0.5928 - val_loss: 1.0454 - val_accuracy: 0.6222
#
# Epoch 00026: val_accuracy improved from 0.61111 to 0.62222, saving model to best_model_224px.h5
# Epoch 27/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.0676 - accuracy: 0.6031 - val_loss: 1.1076 - val_accuracy: 0.5910
#
# Epoch 00027: val_accuracy did not improve from 0.62222
# Epoch 28/85
# 53/53 [==============================] - 334s 6s/step - loss: 1.0427 - accuracy: 0.6170 - val_loss: 1.0657 - val_accuracy: 0.6049
#
# Epoch 00028: val_accuracy did not improve from 0.62222
# Epoch 29/85
# 53/53 [==============================] - 335s 6s/step - loss: 1.0327 - accuracy: 0.6203 - val_loss: 1.0414 - val_accuracy: 0.6215
#
# Epoch 00029: val_accuracy did not improve from 0.62222
# Epoch 30/85
# 53/53 [==============================] - 332s 6s/step - loss: 1.0768 - accuracy: 0.6110 - val_loss: 1.0864 - val_accuracy: 0.5910
#
# Epoch 00030: val_accuracy did not improve from 0.62222
# Epoch 31/85
# 53/53 [==============================] - 329s 6s/step - loss: 1.0339 - accuracy: 0.6092 - val_loss: 1.0454 - val_accuracy: 0.6111
#
# Epoch 00031: val_accuracy did not improve from 0.62222
# Epoch 32/85
# 53/53 [==============================] - 327s 6s/step - loss: 0.9953 - accuracy: 0.6357 - val_loss: 1.1317 - val_accuracy: 0.5785
#
# Epoch 00032: val_accuracy did not improve from 0.62222
# Epoch 33/85
# 53/53 [==============================] - 327s 6s/step - loss: 0.9974 - accuracy: 0.6341 - val_loss: 1.0575 - val_accuracy: 0.6035
#
# Epoch 00033: val_accuracy did not improve from 0.62222
# Epoch 34/85
# 53/53 [==============================] - 327s 6s/step - loss: 1.0176 - accuracy: 0.6301 - val_loss: 1.0274 - val_accuracy: 0.6194
#
# Epoch 00034: val_accuracy did not improve from 0.62222
# Epoch 35/85
# 53/53 [==============================] - 328s 6s/step - loss: 0.9307 - accuracy: 0.6567 - val_loss: 1.0192 - val_accuracy: 0.6271
#
# Epoch 00035: val_accuracy improved from 0.62222 to 0.62708, saving model to best_model_224px.h5
# Epoch 36/85
# 53/53 [==============================] - 327s 6s/step - loss: 0.9294 - accuracy: 0.6552 - val_loss: 1.0061 - val_accuracy: 0.6250
#
# Epoch 00036: val_accuracy did not improve from 0.62708
# Epoch 37/85
# 53/53 [==============================] - 332s 6s/step - loss: 0.9372 - accuracy: 0.6539 - val_loss: 1.1249 - val_accuracy: 0.5889
#
# Epoch 00037: val_accuracy did not improve from 0.62708
# Epoch 38/85
# 53/53 [==============================] - 359s 7s/step - loss: 0.9147 - accuracy: 0.6681 - val_loss: 1.1352 - val_accuracy: 0.5993
# Epoch 00038: val_accuracy did not improve from 0.62708
# Epoch 39/85
# 53/53 [==============================] - 338s 6s/step - loss: 0.9078 - accuracy: 0.6590 - val_loss: 1.2670 - val_accuracy: 0.5562
#
# Epoch 00039: val_accuracy did not improve from 0.62708
# Epoch 40/85
# 53/53 [==============================] - 336s 6s/step - loss: 0.9214 - accuracy: 0.6514 - val_loss: 1.0842 - val_accuracy: 0.6028
#
# Epoch 00040: val_accuracy did not improve from 0.62708
# Epoch 41/85
# 53/53 [==============================] - 334s 6s/step - loss: 0.8847 - accuracy: 0.6732 - val_loss: 1.1661 - val_accuracy: 0.5819
#
# Epoch 00041: val_accuracy did not improve from 0.62708
# Epoch 42/85
# 53/53 [==============================] - 343s 6s/step - loss: 0.8506 - accuracy: 0.6828 - val_loss: 1.0871 - val_accuracy: 0.6215
#
# Epoch 00042: val_accuracy did not improve from 0.62708
# Epoch 43/85
# 53/53 [==============================] - 339s 6s/step - loss: 0.9311 - accuracy: 0.6597 - val_loss: 1.1820 - val_accuracy: 0.5882
#
# Epoch 00043: val_accuracy did not improve from 0.62708
# Epoch 44/85
# 53/53 [==============================] - 348s 7s/step - loss: 0.8313 - accuracy: 0.7000 - val_loss: 1.1131 - val_accuracy: 0.6028
#
# Epoch 00044: val_accuracy did not improve from 0.62708
# Epoch 45/85
# 53/53 [==============================] - 343s 6s/step - loss: 0.8142 - accuracy: 0.6895 - val_loss: 1.0761 - val_accuracy: 0.6146
#
# Epoch 00045: val_accuracy did not improve from 0.62708
# Epoch 46/85
# 53/53 [==============================] - 345s 7s/step - loss: 0.8320 - accuracy: 0.6898 - val_loss: 1.0717 - val_accuracy: 0.6292
#
# Epoch 00046: val_accuracy improved from 0.62708 to 0.62917, saving model to best_model_224px.h5
# Epoch 00046: early stopping

# %%
# Create a new model instance to upload the best saved model there
# because our trained model finished training with the final accuracy not the best possible
model = model_with_dropout()

# Load the previously saved weights
model.load_weights('best_model_224px.h5')
# Evaluate model

_, acc = model.evaluate_generator(test_set, steps=len(test_set), verbose=0)
print("Best accuracy: %.4f" % (acc * 100.0))
# Out:
# Accuracy: 62.9167

# %%
# Build graphs of entropy loss and accuracy
graph_accuracy_loss(history)

# %%
# As we see after 46 epochs our model didn't reached higher level of accuracy,
# and wasn't improving val_loss for 10 epochs so early stop was executed.
# and finished with the best accuracy score 62.9167%.
# Due the fact that calculations are computationally expensive for bigger picture size 
# we would recomment to use a model trained on small pictures of size 128*128px

# %% [markdown]
# <h3>Model with 3 VGG blocks, dropout, data augmentation and batch normalization</h3>
# <h4>Trained for 85 max epochs and small size of pictures (128*128px) with Early stopping</h4>

# %%
# Implementing Early stoping
ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience= 20)
# Save chekpoints to 
MC = ModelCheckpoint('best_model_bn.h5', monitor='val_accuracy', 
                     verbose=1, save_best_only=True, save_weights_only=False, mode='auto')

# %%
# Let's improve our model's architecture:
# - add batch normalization between layers to speed up training

# %%
# Define CNN model with added BatchNormalization
img_rows = 128
img_cols = 128
def model_blocks_bn():
    #reset_random_seeds()
    model = Sequential()
# Batch Normalization added to every block
# 1 block
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(img_rows, img_cols, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    
# 2 block
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
    
# 3 block
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))
   
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu', name='fc1'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='softmax', name='output'))
    # Compilation of a model
    opt = SGD(lr=0.001, momentum=0.9) # Gradient descent (with momentum) optimizer.
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Create data generators
train_datagen = ImageDataGenerator(rescale=1. / 255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   fill_mode='nearest')
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Create sets
training_set = train_datagen.flow_from_directory('train',
                                                 target_size=(img_rows, img_cols),
                                                 batch_size=batch_size,
                                                 class_mode='categorical')


test_set = test_datagen.flow_from_directory('val',
                                            target_size=(img_rows, img_cols),
                                            batch_size=batch_size, shuffle = False,
                                            class_mode='categorical')

# Define model
model_bn = model_blocks_bn()
# Fit model
history = model_bn.fit_generator(training_set, 
                              steps_per_epoch=len(training_set),
                              validation_data=test_set, 
                              validation_steps=len(test_set), 
                              epochs= 85, callbacks = [ES, MC])
# Out:
# Found 3360 images belonging to 6 classes.
# Found 1440 images belonging to 6 classes.
# Epoch 1/85
# 53/53 [==============================] - 19s 346ms/step - loss: 2.2054 - accuracy: 0.3445 - val_loss: 2.2370 - val_accuracy: 0.1681
#
# Epoch 00001: val_accuracy improved from -inf to 0.16806, saving model to best_model_bn.h5
# Epoch 2/85
# 53/53 [==============================] - 18s 339ms/step - loss: 1.5403 - accuracy: 0.4837 - val_loss: 4.9748 - val_accuracy: 0.1667
#
# Epoch 00002: val_accuracy did not improve from 0.16806
# Epoch 3/85
# 53/53 [==============================] - 18s 337ms/step - loss: 1.3735 - accuracy: 0.5216 - val_loss: 2.4959 - val_accuracy: 0.2222
#
# Epoch 00003: val_accuracy improved from 0.16806 to 0.22222, saving model to best_model_bn.h5
# Epoch 4/85
# 53/53 [==============================] - 18s 341ms/step - loss: 1.2607 - accuracy: 0.5533 - val_loss: 2.7830 - val_accuracy: 0.2118
#
# Epoch 00004: val_accuracy did not improve from 0.22222
# Epoch 5/85
# 53/53 [==============================] - 18s 341ms/step - loss: 1.1264 - accuracy: 0.5969 - val_loss: 2.5709 - val_accuracy: 0.2153
#
# Epoch 00005: val_accuracy did not improve from 0.22222
# Epoch 6/85
# 53/53 [==============================] - 18s 339ms/step - loss: 1.0890 - accuracy: 0.6071 - val_loss: 2.2061 - val_accuracy: 0.2924
#
# Epoch 00006: val_accuracy improved from 0.22222 to 0.29236, saving model to best_model_bn.h5
# Epoch 7/85
# 53/53 [==============================] - 18s 338ms/step - loss: 1.0427 - accuracy: 0.6226 - val_loss: 2.0799 - val_accuracy: 0.3458
#
# Epoch 00007: val_accuracy improved from 0.29236 to 0.34583, saving model to best_model_bn.h5
# Epoch 8/85
# 53/53 [==============================] - 18s 343ms/step - loss: 0.9754 - accuracy: 0.6487 - val_loss: 1.5729 - val_accuracy: 0.4313
#
# Epoch 00008: val_accuracy improved from 0.34583 to 0.43125, saving model to best_model_bn.h5
# Epoch 9/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.9585 - accuracy: 0.6557 - val_loss: 1.6737 - val_accuracy: 0.4181
#
# Epoch 00009: val_accuracy did not improve from 0.43125
# Epoch 10/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.8997 - accuracy: 0.6728 - val_loss: 1.6112 - val_accuracy: 0.4854
#
# Epoch 00010: val_accuracy improved from 0.43125 to 0.48542, saving model to best_model_bn.h5
# Epoch 11/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.9320 - accuracy: 0.6633 - val_loss: 2.0031 - val_accuracy: 0.3826
#
# Epoch 00011: val_accuracy did not improve from 0.48542
# Epoch 12/85
# 53/53 [==============================] - 18s 341ms/step - loss: 0.9229 - accuracy: 0.6748 - val_loss: 1.4785 - val_accuracy: 0.4993
#
# Epoch 00012: val_accuracy improved from 0.48542 to 0.49931, saving model to best_model_bn.h5
# Epoch 13/85
# 53/53 [==============================] - 18s 339ms/step - loss: 0.8209 - accuracy: 0.7126 - val_loss: 1.3239 - val_accuracy: 0.5431
#
# Epoch 00013: val_accuracy improved from 0.49931 to 0.54306, saving model to best_model_bn.h5
# Epoch 14/85
# 53/53 [==============================] - 18s 336ms/step - loss: 0.8066 - accuracy: 0.7051 - val_loss: 1.3403 - val_accuracy: 0.5556
#
# Epoch 00014: val_accuracy improved from 0.54306 to 0.55556, saving model to best_model_bn.h5
# Epoch 15/85
# 53/53 [==============================] - 18s 346ms/step - loss: 0.8145 - accuracy: 0.7082 - val_loss: 1.4413 - val_accuracy: 0.5493
#
# Epoch 00015: val_accuracy did not improve from 0.55556
# Epoch 16/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.7465 - accuracy: 0.7373 - val_loss: 1.5160 - val_accuracy: 0.5125
#
# Epoch 00016: val_accuracy did not improve from 0.55556
# Epoch 17/85
# 53/53 [==============================] - 18s 342ms/step - loss: 0.7082 - accuracy: 0.7443 - val_loss: 1.4763 - val_accuracy: 0.5229
#
# Epoch 00017: val_accuracy did not improve from 0.55556
# Epoch 18/85
# 53/53 [==============================] - 18s 336ms/step - loss: 0.7269 - accuracy: 0.7409 - val_loss: 1.1090 - val_accuracy: 0.6340
#
# Epoch 00018: val_accuracy improved from 0.55556 to 0.63403, saving model to best_model_bn.h5
# Epoch 19/85
# 53/53 [==============================] - 18s 344ms/step - loss: 0.6779 - accuracy: 0.7445 - val_loss: 1.6149 - val_accuracy: 0.4840
#
# Epoch 00019: val_accuracy did not improve from 0.63403
# Epoch 20/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.6261 - accuracy: 0.7619 - val_loss: 1.2255 - val_accuracy: 0.6132
#
# Epoch 00020: val_accuracy did not improve from 0.63403
# Epoch 21/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.6043 - accuracy: 0.7847 - val_loss: 1.4254 - val_accuracy: 0.5542
#
# Epoch 00021: val_accuracy did not improve from 0.63403
# Epoch 22/85
# 53/53 [==============================] - 18s 342ms/step - loss: 0.5936 - accuracy: 0.7863 - val_loss: 1.5710 - val_accuracy: 0.5132
#
# Epoch 00022: val_accuracy did not improve from 0.63403
# Epoch 23/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.5499 - accuracy: 0.8128 - val_loss: 1.2029 - val_accuracy: 0.6014
#
# Epoch 00023: val_accuracy did not improve from 0.63403
# Epoch 24/85
# 53/53 [==============================] - 18s 341ms/step - loss: 0.5783 - accuracy: 0.7926 - val_loss: 1.3017 - val_accuracy: 0.5792
#
# Epoch 00024: val_accuracy did not improve from 0.63403
# Epoch 25/85
# 53/53 [==============================] - 18s 342ms/step - loss: 0.5617 - accuracy: 0.7997 - val_loss: 1.4060 - val_accuracy: 0.5708
#
# Epoch 00025: val_accuracy did not improve from 0.63403
# Epoch 26/85
# 53/53 [==============================] - 18s 338ms/step - loss: 0.5458 - accuracy: 0.8064 - val_loss: 1.3926 - val_accuracy: 0.5611
#
# Epoch 00026: val_accuracy did not improve from 0.63403
# Epoch 27/85
# 53/53 [==============================] - 18s 335ms/step - loss: 0.5200 - accuracy: 0.8107 - val_loss: 1.2561 - val_accuracy: 0.6049
#
# Epoch 00027: val_accuracy did not improve from 0.63403
# Epoch 28/85
# 53/53 [==============================] - 18s 340ms/step - loss: 0.4908 - accuracy: 0.8213 - val_loss: 1.3079 - val_accuracy: 0.5993
#
# Epoch 00028: val_accuracy did not improve from 0.63403
# Epoch 00028: early stopping

# %%
# Create a new model instance to upload the best saved model there
# because our trained model finished training with the final accuracy not the best possible
model = model_blocks_bn()

# Load the previously saved weights
model.load_weights('best_model_bn.h5')
# Evaluate model

_, acc = model.evaluate_generator(test_set, steps=len(test_set), verbose=0)
print("Best accuracy: %.4f" % (acc * 100.0))
# Out:
# Accuracy: 63.4028

# %%
# Build graphs of entropy loss and accuracy
graph_accuracy_loss(history)

# %%
# As we see our model with batch normalization learns much faster.
#  but it is still has lower accuracy and has higher overfitting 
# so we are going to use our model_with_dropout (with data augmentation)

# %% [markdown]
# <h3>Model VGG16</h3>

# %%
# The architecture of VGG16 was used here just for comparison of time needed to train this model

# %%
# Implementing Early stoping and saving chekpoints
ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
MC = ModelCheckpoint('best_model__vgg16.h5', monitor='val_accuracy', 
                     verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
img_rows = 224
img_cols = 224

# Define VGG16 model 
def VGG16():
    model = Sequential()
    model.add(Conv2D(input_shape=(img_rows,img_cols,3),filters=64, kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
    
    model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
    
    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
    
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
    
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),name='vgg16'))
   
    model.add(Flatten(name='flatten'))
    model.add(Dense(units=4096, activation="relu", name='fc1'))
    model.add(Dense(units=4096,activation="relu", name='fc2'))
    model.add(Dense(units=6, activation='softmax', name='output'))
    
    opt = SGD(lr=0.001, momentum=0.9) # Gradient descent (with momentum) optimizer.
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Create sets
training_set = train_datagen.flow_from_directory('train',
                                                 target_size=(img_rows, img_cols),
                                                 batch_size=batch_size,
                                                 class_mode='categorical')


test_set = test_datagen.flow_from_directory('val',
                                            target_size=(img_rows, img_cols),
                                            batch_size=batch_size, shuffle = False,
                                            class_mode='categorical')

# Define model
model_vgg = VGG16()
# Fit model
history = model_vgg.fit_generator(training_set, 
                              steps_per_epoch=len(training_set),
                              validation_data=test_set, 
                              validation_steps=len(test_set), 
                              epochs= 85, callbacks=[ES, MC])
# Out:
# Found 3360 images belonging to 6 classes.
# Found 1440 images belonging to 6 classes.
# Epoch 1/100
# 53/53 [==============================] - 88s 1s/step - loss: 1.7917 - accuracy: 0.1704 - val_loss: 1.7912 - val_accuracy: 0.1674
#
# Epoch 00001: val_accuracy improved from -inf to 0.16736, saving model to best_model__vgg16.h5
# Epoch 2/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7911 - accuracy: 0.1846 - val_loss: 1.7907 - val_accuracy: 0.3139
#
# Epoch 00002: val_accuracy improved from 0.16736 to 0.31389, saving model to best_model__vgg16.h5
# Epoch 3/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7906 - accuracy: 0.2964 - val_loss: 1.7902 - val_accuracy: 0.3479
#
# Epoch 00003: val_accuracy improved from 0.31389 to 0.34792, saving model to best_model__vgg16.h5
# Epoch 4/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7899 - accuracy: 0.3157 - val_loss: 1.7896 - val_accuracy: 0.3556
#
# Epoch 00004: val_accuracy improved from 0.34792 to 0.35556, saving model to best_model__vgg16.h5
# Epoch 5/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7893 - accuracy: 0.2807 - val_loss: 1.7888 - val_accuracy: 0.3153
#
# Epoch 00005: val_accuracy did not improve from 0.35556
# Epoch 6/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7884 - accuracy: 0.3234 - val_loss: 1.7877 - val_accuracy: 0.3556
#
# Epoch 00006: val_accuracy did not improve from 0.35556
# Epoch 7/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7868 - accuracy: 0.3214 - val_loss: 1.7861 - val_accuracy: 0.3764
#
# Epoch 00007: val_accuracy improved from 0.35556 to 0.37639, saving model to best_model__vgg16.h5
# Epoch 8/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7855 - accuracy: 0.3180 - val_loss: 1.7838 - val_accuracy: 0.3528
#
# Epoch 00008: val_accuracy did not improve from 0.37639
# Epoch 9/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7826 - accuracy: 0.3394 - val_loss: 1.7801 - val_accuracy: 0.3375
#
# Epoch 00009: val_accuracy did not improve from 0.37639
# Epoch 10/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7788 - accuracy: 0.3328 - val_loss: 1.7739 - val_accuracy: 0.3028
#
# Epoch 00010: val_accuracy did not improve from 0.37639
# Epoch 11/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7708 - accuracy: 0.3182 - val_loss: 1.7595 - val_accuracy: 0.3201
#
# Epoch 00011: val_accuracy did not improve from 0.37639
# Epoch 12/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.7501 - accuracy: 0.3157 - val_loss: 1.7193 - val_accuracy: 0.3146
#
# Epoch 00012: val_accuracy did not improve from 0.37639
# Epoch 13/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.6971 - accuracy: 0.3280 - val_loss: 1.6250 - val_accuracy: 0.3382
#
# Epoch 00013: val_accuracy did not improve from 0.37639
# Epoch 14/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.6378 - accuracy: 0.3181 - val_loss: 1.6187 - val_accuracy: 0.3167
#
# Epoch 00014: val_accuracy did not improve from 0.37639
# Epoch 15/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.6139 - accuracy: 0.3244 - val_loss: 1.5730 - val_accuracy: 0.3576
#
# Epoch 00015: val_accuracy did not improve from 0.37639
# Epoch 16/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.5878 - accuracy: 0.3412 - val_loss: 1.6184 - val_accuracy: 0.3347
#
# Epoch 00016: val_accuracy did not improve from 0.37639
# Epoch 17/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.5960 - accuracy: 0.3472 - val_loss: 1.5543 - val_accuracy: 0.3819
#
# Epoch 00017: val_accuracy improved from 0.37639 to 0.38194, saving model to best_model__vgg16.h5
# Epoch 18/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.5635 - accuracy: 0.3721 - val_loss: 1.5769 - val_accuracy: 0.3604
#
# Epoch 00018: val_accuracy did not improve from 0.38194
# Epoch 19/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.5591 - accuracy: 0.3839 - val_loss: 1.5782 - val_accuracy: 0.3694
#
# Epoch 00019: val_accuracy did not improve from 0.38194
# Epoch 20/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.5228 - accuracy: 0.3809 - val_loss: 1.5893 - val_accuracy: 0.3507
#
# Epoch 00020: val_accuracy did not improve from 0.38194
# Epoch 21/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.5543 - accuracy: 0.3641 - val_loss: 1.5140 - val_accuracy: 0.4021
#
# Epoch 00021: val_accuracy improved from 0.38194 to 0.40208, saving model to best_model__vgg16.h5
# Epoch 22/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4937 - accuracy: 0.3948 - val_loss: 1.5129 - val_accuracy: 0.3896
#
# Epoch 00022: val_accuracy did not improve from 0.40208
# Epoch 23/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.5237 - accuracy: 0.3848 - val_loss: 1.5063 - val_accuracy: 0.4056
#
# Epoch 00023: val_accuracy improved from 0.40208 to 0.40556, saving model to best_model__vgg16.h5
# Epoch 24/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4921 - accuracy: 0.4089 - val_loss: 1.5158 - val_accuracy: 0.4097
#
# Epoch 00024: val_accuracy improved from 0.40556 to 0.40972, saving model to best_model__vgg16.h5
# Epoch 25/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4865 - accuracy: 0.4275 - val_loss: 1.5385 - val_accuracy: 0.3903
#
# Epoch 00025: val_accuracy did not improve from 0.40972
# Epoch 26/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4832 - accuracy: 0.4054 - val_loss: 1.4817 - val_accuracy: 0.4076
#
# Epoch 00026: val_accuracy did not improve from 0.40972
# Epoch 27/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4447 - accuracy: 0.4341 - val_loss: 1.4840 - val_accuracy: 0.4167
#
# Epoch 00027: val_accuracy improved from 0.40972 to 0.41667, saving model to best_model__vgg16.h5
# Epoch 28/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4351 - accuracy: 0.4519 - val_loss: 1.5899 - val_accuracy: 0.3611
#
# Epoch 00028: val_accuracy did not improve from 0.41667
# Epoch 29/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4749 - accuracy: 0.4172 - val_loss: 1.4764 - val_accuracy: 0.4285
#
# Epoch 00029: val_accuracy improved from 0.41667 to 0.42847, saving model to best_model__vgg16.h5
# Epoch 30/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4381 - accuracy: 0.4504 - val_loss: 1.4602 - val_accuracy: 0.4285
#
# Epoch 00030: val_accuracy did not improve from 0.42847
# Epoch 31/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.4127 - accuracy: 0.4511 - val_loss: 1.4563 - val_accuracy: 0.4181
#
# Epoch 00031: val_accuracy did not improve from 0.42847
# Epoch 32/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.3861 - accuracy: 0.4716 - val_loss: 1.4484 - val_accuracy: 0.4347
#
# Epoch 00032: val_accuracy improved from 0.42847 to 0.43472, saving model to best_model__vgg16.h5
# Epoch 33/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.3669 - accuracy: 0.4665 - val_loss: 1.4356 - val_accuracy: 0.4354
#
# Epoch 00033: val_accuracy improved from 0.43472 to 0.43542, saving model to best_model__vgg16.h5
# Epoch 34/100
# 53/53 [==============================] - 60s 1s/step - loss: 1.3439 - accuracy: 0.4880 - val_loss: 1.4517 - val_accuracy: 0.4236
#
# Epoch 00034: val_accuracy did not improve from 0.43542
# Epoch 35/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.3458 - accuracy: 0.4872 - val_loss: 1.4321 - val_accuracy: 0.4493
#
# Epoch 00035: val_accuracy improved from 0.43542 to 0.44931, saving model to best_model__vgg16.h5
# Epoch 36/100
# 53/53 [==============================] - 60s 1s/step - loss: 1.3308 - accuracy: 0.4868 - val_loss: 1.4522 - val_accuracy: 0.4347
#
# Epoch 00036: val_accuracy did not improve from 0.44931
# Epoch 37/100
# 53/53 [==============================] - 60s 1s/step - loss: 1.3064 - accuracy: 0.4991 - val_loss: 1.4396 - val_accuracy: 0.4340
#
# Epoch 00037: val_accuracy did not improve from 0.44931
# Epoch 38/100
# 53/53 [==============================] - 60s 1s/step - loss: 1.3009 - accuracy: 0.4967 - val_loss: 1.3909 - val_accuracy: 0.4715
#
# Epoch 00038: val_accuracy improved from 0.44931 to 0.47153, saving model to best_model__vgg16.h5
# Epoch 39/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.2785 - accuracy: 0.5074 - val_loss: 1.4185 - val_accuracy: 0.4653
#
# Epoch 00039: val_accuracy did not improve from 0.47153
# Epoch 40/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.2316 - accuracy: 0.5398 - val_loss: 1.4458 - val_accuracy: 0.4437
#
# Epoch 00040: val_accuracy did not improve from 0.47153
# Epoch 41/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.2128 - accuracy: 0.5414 - val_loss: 1.3704 - val_accuracy: 0.4715
#
# Epoch 00041: val_accuracy did not improve from 0.47153
# Epoch 42/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.1940 - accuracy: 0.5575 - val_loss: 1.4260 - val_accuracy: 0.4389
#
# Epoch 00042: val_accuracy did not improve from 0.47153
# Epoch 43/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.1895 - accuracy: 0.5575 - val_loss: 1.3607 - val_accuracy: 0.4917
#
# Epoch 00043: val_accuracy improved from 0.47153 to 0.49167, saving model to best_model__vgg16.h5
# Epoch 44/100
# 53/53 [==============================] - 60s 1s/step - loss: 1.1897 - accuracy: 0.5540 - val_loss: 1.3392 - val_accuracy: 0.4896
#
# Epoch 00044: val_accuracy did not improve from 0.49167
# Epoch 45/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.1261 - accuracy: 0.5938 - val_loss: 1.3885 - val_accuracy: 0.4910
#
# Epoch 00045: val_accuracy did not improve from 0.49167
# Epoch 46/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.1057 - accuracy: 0.5897 - val_loss: 1.4202 - val_accuracy: 0.4472
#
# Epoch 00046: val_accuracy did not improve from 0.49167
# Epoch 47/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.0894 - accuracy: 0.6031 - val_loss: 1.3819 - val_accuracy: 0.4806
#
# Epoch 00047: val_accuracy did not improve from 0.49167
# Epoch 48/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.0701 - accuracy: 0.6056 - val_loss: 1.4541 - val_accuracy: 0.4667
#
# Epoch 00048: val_accuracy did not improve from 0.49167
# Epoch 49/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.0764 - accuracy: 0.6107 - val_loss: 1.5628 - val_accuracy: 0.4389
#
# Epoch 00049: val_accuracy did not improve from 0.49167
# Epoch 50/100
# 53/53 [==============================] - 59s 1s/step - loss: 1.0284 - accuracy: 0.6230 - val_loss: 1.4387 - val_accuracy: 0.4771
#
# Epoch 00050: val_accuracy did not improve from 0.49167
# Epoch 51/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.9710 - accuracy: 0.6498 - val_loss: 1.4277 - val_accuracy: 0.4479
#
# Epoch 00051: val_accuracy did not improve from 0.49167
# Epoch 52/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.9187 - accuracy: 0.6767 - val_loss: 1.4663 - val_accuracy: 0.4785
#
# Epoch 00052: val_accuracy did not improve from 0.49167
# Epoch 53/100
# 53/53 [==============================] - 60s 1s/step - loss: 0.9212 - accuracy: 0.6601 - val_loss: 1.4869 - val_accuracy: 0.4826
#
# Epoch 00053: val_accuracy did not improve from 0.49167
# Epoch 54/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.8779 - accuracy: 0.6788 - val_loss: 1.4740 - val_accuracy: 0.5007
#
# Epoch 00054: val_accuracy improved from 0.49167 to 0.50069, saving model to best_model__vgg16.h5
# Epoch 55/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.8145 - accuracy: 0.7022 - val_loss: 1.5197 - val_accuracy: 0.5000
#
# Epoch 00055: val_accuracy did not improve from 0.50069
# Epoch 56/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.7926 - accuracy: 0.7162 - val_loss: 1.6427 - val_accuracy: 0.4757
#
# Epoch 00056: val_accuracy did not improve from 0.50069
# Epoch 57/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.8159 - accuracy: 0.7013 - val_loss: 1.7825 - val_accuracy: 0.4181
#
# Epoch 00057: val_accuracy did not improve from 0.50069
# Epoch 58/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.8530 - accuracy: 0.6804 - val_loss: 1.5420 - val_accuracy: 0.4660
#
# Epoch 00058: val_accuracy did not improve from 0.50069
# Epoch 59/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.6653 - accuracy: 0.7644 - val_loss: 1.5724 - val_accuracy: 0.4882
#
# Epoch 00059: val_accuracy did not improve from 0.50069
# Epoch 60/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.6634 - accuracy: 0.7675 - val_loss: 1.6213 - val_accuracy: 0.4806
#
# Epoch 00060: val_accuracy did not improve from 0.50069
# Epoch 61/100
# 53/53 [==============================] - 60s 1s/step - loss: 0.6046 - accuracy: 0.7869 - val_loss: 1.7276 - val_accuracy: 0.4778
#
# Epoch 00061: val_accuracy did not improve from 0.50069
# Epoch 62/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.5436 - accuracy: 0.8142 - val_loss: 1.7836 - val_accuracy: 0.4882
#
# Epoch 00062: val_accuracy did not improve from 0.50069
# Epoch 63/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.5331 - accuracy: 0.8082 - val_loss: 1.8123 - val_accuracy: 0.4799
#
# Epoch 00063: val_accuracy did not improve from 0.50069
# Epoch 64/100
# 53/53 [==============================] - 59s 1s/step - loss: 0.4887 - accuracy: 0.8220 - val_loss: 1.9326 - val_accuracy: 0.4750
#
# Epoch 00064: val_accuracy did not improve from 0.50069
# Epoch 00064: early stopping

# %%
# Create a new model instance to upload the best saved model there
# because our trained model finished training with the final accuracy not the best possible
model = VGG16()

# Load the previously saved weights
model.load_weights('best_model__vgg16.h5')

# Evaluate model

_, acc = model.evaluate_generator(test_set, steps=len(test_set), verbose=0)
print("Best accuracy: %.4f" % (acc * 100.0))
# Out:
# Accuracy: 50.0694

# %%
# Build graphs of entropy loss and accuracy
graph_accuracy_loss(history)

# %%
# As we see vgg16 needs a lot of time to train and didn't achieve higher level of accuracy
# for our dataset.
# And per project explanation we can't use pre-trained models

# %% [markdown]
# # Filters

# %%
# For appear always the same first picture need have 'suffle=False' in flow_from_directory

# test_set contain 1440 images and they are divided in batch_size
# 1st batch_size has 64 images
# totally exist 22 batch_size with 64 images and 1 batch_size with 32 images

# %%
# Define images array
image_test = []
# Define images labels
labels_test = []
for image, label in test_set:
    image_test = image
    #(number of pictures, img_rows, img_cols, dimention)
    print(image_test.shape)
    labels_test = label
    #(number of pictures, number of artists)
    print(labels_test.shape)
    
    
    # only for show if it is working    
    plt.figure()
    plt.imshow(image[0])
    plt.grid(False)
    plt.show()
    
    break
# Out:
# (64, 128, 128, 3)
# (64, 6)

# %% [markdown]
# #### All layers in subplots ploting the same number of filters

# %%
# Visualize feature maps output from each block in the vgg model

# load the model
model = model_best

# show all filters
ixs = [0,1,2,3,4,5,6,7,8]
outputs = [model.layers[i].output for i in ixs]
model = Model(inputs=model.inputs, outputs=outputs)
model.summary()
# load the image with the required shape

# Define only one picture to try if it is working with image test
img = image_test[0]

# convert the image to an array
img = img_to_array(img)
# expand dimensions so that it represents a single 'sample'
img = expand_dims(img, axis=0)
# get feature map for first hidden layer
feature_maps = model.predict(img)
# plot the output from each block

# plot all 32 maps in an 4x8 squares
# as the 1st number of filters defined in the model was 32
rows = 4
cols = 8

for fmap in feature_maps:
    # plot all 32 maps in an 4x8 squares
    ix = 1
    
    for _ in range(rows):
        
        for _ in range(cols):
            # specify subplot and turn of axis
            ax = pyplot.subplot(rows, cols, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            
            
            # plot filter channel in grayscale
            pyplot.imshow(fmap[0, :, :, ix-1],
                          cmap='gray'
                         )
            ix += 1

# show the figure
    pyplot.show()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18_input (InputLayer) [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 128, 128, 32)      896
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 64, 64, 64)        18496
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 16, 128)       0
# =================================================================
# Total params: 287,008
# Trainable params: 287,008
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Each layer with the number of filters that this layer has

# %%
# Define function
def filters(layer_number, rows, cols, picture_n):
    model = model_best
    # redefine model to output right after the first hidden layer
    model = Model(inputs=model.inputs, outputs=model.layers[layer_number].output)
    #model.summary()
    # load the image with the required shape
    img = image_test[picture_n]
    # convert the image to an array
    img = img_to_array(img)
    # expand dimensions so that it represents a single 'sample'
    img = expand_dims(img, axis=0)
    # get feature map for first hidden layer
    feature_maps = model.predict(img)
    # plot all 64 maps in an 8x8 squares
    rows = rows
    cols = cols
    ix = 1
    for _ in range(rows):
        for _ in range(cols):
            # specify subplot and turn of axis
            ax = pyplot.subplot(rows, cols, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            # plot filter channel in grayscale
            pyplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
            ix += 1
    # show the figure
    pyplot.show()
    return

# %%
filters(layer_number = 2, rows = 4, cols = 8, picture_n = 0)

# %%
filters(layer_number = 5, rows = 8, cols = 8, picture_n = 0)

# %%
filters(layer_number = 8, rows = 8, cols = 16, picture_n = 0)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f14345f49e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# # Predict artist

# %%
predictions = model_best.predict(test_set)
predictions[0]
# Out:
# array([9.9981004e-01, 8.6796506e-05, 1.2181960e-06, 3.2554435e-05,
#        3.8441627e-05, 3.1050298e-05], dtype=float32)

# %%
# Prediction label
print(np.argmax(predictions[0]))
print(predictions[0])

# Real label
print(np.argmax(labels_test[0]))
print(labels_test[0])
# Out:
# 0
# [9.9981004e-01 8.6796506e-05 1.2181960e-06 3.2554435e-05 3.8441627e-05
#  3.1050298e-05]
# 0
# [1. 0. 0. 0. 0. 0.]

# %%
# autors name to add in graph below
artists_name = os.listdir('val')
artists_name
# Out:
# ['Matisse', 'Monet', 'Pissaro', 'Renoir', 'Sargent', 'VanGogh']

# %%
plt.figure(figsize=(11,5))
plt.subplot(1,2,1)

# select one picture in test
plt.imshow(image_test[0])
plt.subplot(2,2,2)
plt.bar(artists_name, labels_test[0],color = 'C1')
plt.subplot(2,2,4)
plt.bar(artists_name, predictions[0])
plt.ylim(0, 1)
plt.show()

# %%
# ! git clone https://github.com/svasylyeva/AWS
# Out:
# Cloning into 'AWS'...
# remote: Enumerating objects: 4824, done.
# remote: Counting objects: 100% (4824/4824), done.
# remote: Compressing objects: 100% (4824/4824), done.
# remote: Total 4824 (delta 4), reused 4816 (delta 0), pack-reused 0
# Receiving objects: 100% (4824/4824), 73.31 MiB | 43.00 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
cd AWS
# Out:
# /content/AWS

# %%
# !ls
# Out:
# train  val

# %%
rm Code_128px_35_folders.ipynb
